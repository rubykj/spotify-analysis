# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Spotify-Playlist-Analysis" data-toc-modified-id="Spotify-Playlist-Analysis-0.1"><span class="toc-item-num">0.1&nbsp;&nbsp;</span>Spotify Playlist Analysis</a></span></li><li><span><a href="#Assumptions" data-toc-modified-id="Assumptions-0.2"><span class="toc-item-num">0.2&nbsp;&nbsp;</span>Assumptions</a></span></li></ul></li><li><span><a href="#Data-Collection-&amp;-Wrangling" data-toc-modified-id="Data-Collection-&amp;-Wrangling-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Data Collection &amp; Wrangling</a></span></li><li><span><a href="#Data-Manipulation-&amp;-Formatting" data-toc-modified-id="Data-Manipulation-&amp;-Formatting-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Data Manipulation &amp; Formatting</a></span><ul class="toc-item"><li><span><a href="#From-looking-at-the-first-few-rows" data-toc-modified-id="From-looking-at-the-first-few-rows-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>From looking at the first few rows</a></span></li><li><span><a href="#Columns-to-be-modified" data-toc-modified-id="Columns-to-be-modified-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Columns to be modified</a></span></li><li><span><a href="#New-columns-to-be-added" data-toc-modified-id="New-columns-to-be-added-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>New columns to be added</a></span><ul class="toc-item"><li><span><a href="#Release-Date" data-toc-modified-id="Release-Date-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>Release Date</a></span></li><li><span><a href="#Duration" data-toc-modified-id="Duration-2.3.2"><span class="toc-item-num">2.3.2&nbsp;&nbsp;</span>Duration</a></span></li><li><span><a href="#Tempo" data-toc-modified-id="Tempo-2.3.3"><span class="toc-item-num">2.3.3&nbsp;&nbsp;</span>Tempo</a></span></li><li><span><a href="#Key" data-toc-modified-id="Key-2.3.4"><span class="toc-item-num">2.3.4&nbsp;&nbsp;</span>Key</a></span></li><li><span><a href="#Mode" data-toc-modified-id="Mode-2.3.5"><span class="toc-item-num">2.3.5&nbsp;&nbsp;</span>Mode</a></span></li><li><span><a href="#Key_Mode" data-toc-modified-id="Key_Mode-2.3.6"><span class="toc-item-num">2.3.6&nbsp;&nbsp;</span>Key_Mode</a></span></li><li><span><a href="#Audio-features" data-toc-modified-id="Audio-features-2.3.7"><span class="toc-item-num">2.3.7&nbsp;&nbsp;</span>Audio features</a></span></li></ul></li></ul></li><li><span><a href="#Exploratory-Data-Analysis" data-toc-modified-id="Exploratory-Data-Analysis-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Exploratory Data Analysis</a></span><ul class="toc-item"><li><span><a href="#Initial-findings" data-toc-modified-id="Initial-findings-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Initial findings</a></span></li><li><span><a href="#Initial-findings" data-toc-modified-id="Initial-findings-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Initial findings</a></span></li></ul></li><li><span><a href="#Analysis-by-Artist" data-toc-modified-id="Analysis-by-Artist-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Analysis by Artist</a></span><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#How-many-unique-artists-are-there-in-the-top-500?" data-toc-modified-id="How-many-unique-artists-are-there-in-the-top-500?-4.0.0.1"><span class="toc-item-num">4.0.0.1&nbsp;&nbsp;</span>How many unique artists are there in the top 500?</a></span></li><li><span><a href="#Who-are-the-top-artists?" data-toc-modified-id="Who-are-the-top-artists?-4.0.0.2"><span class="toc-item-num">4.0.0.2&nbsp;&nbsp;</span>Who are the top artists?</a></span></li><li><span><a href="#What-percentage-share-of-total-songs-do-the-artists-have?" data-toc-modified-id="What-percentage-share-of-total-songs-do-the-artists-have?-4.0.0.3"><span class="toc-item-num">4.0.0.3&nbsp;&nbsp;</span>What percentage share of total songs do the artists have?</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Analysis-by-Artist-Genres" data-toc-modified-id="Analysis-by-Artist-Genres-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Analysis by Artist Genres</a></span><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#What-are-the-most-frequent-artist-genres?" data-toc-modified-id="What-are-the-most-frequent-artist-genres?-5.0.0.1"><span class="toc-item-num">5.0.0.1&nbsp;&nbsp;</span>What are the most frequent artist genres?</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Analysis-by-Key-and-Mode" data-toc-modified-id="Analysis-by-Key-and-Mode-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Analysis by Key and Mode</a></span><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Are-some-keys-used-more-frequently-than-others-in-popular-songs?" data-toc-modified-id="Are-some-keys-used-more-frequently-than-others-in-popular-songs?-6.0.0.1"><span class="toc-item-num">6.0.0.1&nbsp;&nbsp;</span>Are some keys used more frequently than others in popular songs?</a></span></li></ul></li><li><span><a href="#Mode---What-percentage-of-songs-are-major-or-minor?" data-toc-modified-id="Mode---What-percentage-of-songs-are-major-or-minor?-6.0.1"><span class="toc-item-num">6.0.1&nbsp;&nbsp;</span>Mode - What percentage of songs are major or minor?</a></span></li><li><span><a href="#Explicit---What-percentage-of-songs-are-explicit?" data-toc-modified-id="Explicit---What-percentage-of-songs-are-explicit?-6.0.2"><span class="toc-item-num">6.0.2&nbsp;&nbsp;</span>Explicit - What percentage of songs are explicit?</a></span></li><li><span><a href="#Time-Signature---How-many-different-time-signatures-are-there?" data-toc-modified-id="Time-Signature---How-many-different-time-signatures-are-there?-6.0.3"><span class="toc-item-num">6.0.3&nbsp;&nbsp;</span>Time Signature - How many different time signatures are there?</a></span></li></ul></li></ul></li><li><span><a href="#Analysis-of-Audio-Features" data-toc-modified-id="Analysis-of-Audio-Features-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Analysis of Audio Features</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Is-there-any-correlation-between-these-features?" data-toc-modified-id="Is-there-any-correlation-between-these-features?-7.0.1"><span class="toc-item-num">7.0.1&nbsp;&nbsp;</span>Is there any correlation between these features?</a></span></li><li><span><a href="#Initial-Findings" data-toc-modified-id="Initial-Findings-7.0.2"><span class="toc-item-num">7.0.2&nbsp;&nbsp;</span>Initial Findings</a></span></li><li><span><a href="#Looking-at-'year',-as-time-goes-on:" data-toc-modified-id="Looking-at-'year',-as-time-goes-on:-7.0.3"><span class="toc-item-num">7.0.3&nbsp;&nbsp;</span>Looking at 'year', as time goes on:</a></span></li><li><span><a href="#Compare-the-distribution-of-each-audio-feature." data-toc-modified-id="Compare-the-distribution-of-each-audio-feature.-7.0.4"><span class="toc-item-num">7.0.4&nbsp;&nbsp;</span>Compare the distribution of each audio feature.</a></span></li><li><span><a href="#See-the-same-data-in-a-boxplot" data-toc-modified-id="See-the-same-data-in-a-boxplot-7.0.5"><span class="toc-item-num">7.0.5&nbsp;&nbsp;</span>See the same data in a boxplot</a></span></li></ul></li><li><span><a href="#Change-over-the-years" data-toc-modified-id="Change-over-the-years-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Change over the years</a></span><ul class="toc-item"><li><span><a href="#How-many-songs-in-the-top-500-were-released-under-each-year?" data-toc-modified-id="How-many-songs-in-the-top-500-were-released-under-each-year?-7.1.1"><span class="toc-item-num">7.1.1&nbsp;&nbsp;</span>How many songs in the top 500 were released under each year?</a></span></li><li><span><a href="#Is-there-a-trend-in-audio-features-over-time?" data-toc-modified-id="Is-there-a-trend-in-audio-features-over-time?-7.1.2"><span class="toc-item-num">7.1.2&nbsp;&nbsp;</span>Is there a trend in audio features over time?</a></span></li><li><span><a href="#Is-there-a-trend-in-song-duration-over-time?" data-toc-modified-id="Is-there-a-trend-in-song-duration-over-time?-7.1.3"><span class="toc-item-num">7.1.3&nbsp;&nbsp;</span>Is there a trend in song duration over time?</a></span></li></ul></li><li><span><a href="#Conclusion" data-toc-modified-id="Conclusion-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Conclusion</a></span></li><li><span><a href="#Notes-and-Improvements" data-toc-modified-id="Notes-and-Improvements-7.3"><span class="toc-item-num">7.3&nbsp;&nbsp;</span>Notes and Improvements</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Mini Project 1

# %% [markdown]
# ### Spotify Playlist Analysis

# %% [markdown]
# Spotify is one of the most popular audio streaming and media services provider, founded in 2006.
#
# I will look at the Spotify playlist with the **Top 500 most streamed songs on spotify**. Using information about the tracks, artists and the track audio features, goal is to better understand what are some of the factors that influence songs to be popular.
#
# Similar analysis could help those in the music industry to understand trends in popular music and incorporate into their strategy for creating music.

# %% [markdown]
# ### Assumptions

# %% [markdown]
# - The playlist has the correct top 500
# - In order of most streamed to least streamed

# %%
import json
import spotipy
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Collection & Wrangling

# %% [markdown]
# Through Spotify API, I will retrieve information about tracks, artists and audio features for each track in the playlist.
#
# Firstly set up the client with the authentication details.

# %%
file = 'auth_spotify.json'
auth = json.loads(open(file).read())

# %%
auth.keys()
# Out:
# dict_keys(['client_id', 'client_secret'])

# %%
# set up client with auth
client_credentials_manager = spotipy.SpotifyClientCredentials(client_id=auth['client_id'], client_secret=auth['client_secret'])
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %% [markdown]
# <br>
# Specify URL of the playlist to get URI.

# %%
# Playlist of top 500 most streamed songs
playlist_link = 'https://open.spotify.com/playlist/3RWRqUa3ghwX7ZeXWOReYn?si=f7b5042506f3481d'

# strip URI
playlist_uri = playlist_link.split('/')[-1].split('?')[0]

# %% [markdown]
# <br>
# Retrieve tracks in the playlist using URI.

# %%
playlist = sp.playlist_tracks(playlist_uri)

# %% [markdown]
# Response contains 'items', which is a list of dictionaries, each dictionary corresponding to a track.

# %%
playlist
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/3RWRqUa3ghwX7ZeXWOReYn/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2022-04-05T01:51:41Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/dariuscrowd'},
#     'href': 'https://api.spotify.com/v1/users/dariuscrowd',
#     'id': 'dariuscrowd',
#     'type': 'user',
#     'uri': 'spotify:user:dariuscrowd'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'},
#        'href': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V',
#        'id': '6eUKZXaKkcviH0Ku9w2n3V',
#        'name': 'Ed Sheeran',
#        'type': 'artist',
#        'uri': 'spotify:artist:6eUKZXaKkcviH0Ku9w2n3V'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7oJa8bPFKVbq4c7NswXHw8'},
#      'href': 'https://api.spotify.com/v1/albums/7oJa8bPFKVbq4c7NswXHw8',
#      'id': '7oJa8bPFKVbq4c7NswXHw8',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27383e9b06ccd219248b5301264',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0283e9b06ccd219248b5301264',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485183e9b06ccd219248b5301264',
#        'width': 64}],
#      'name': 'Shape of You',
#      'release_date': '2017-01-06',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:7oJa8bPFKVbq4c7NswXHw8'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'},
#       'href': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V',
#       'id': '6eUKZXaKkcviH0Ku9w2n3V',
#       'name': 'Ed Sheeran',
#       'type': 'artist',
#       'uri': 'spotify:artist:6eUKZXaKkcviH0Ku9w2n3V'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 233712,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAHS1600463'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0FE9t6xYkqWXU2ahLh6D8X'},
#     'href': 'https://api.spotify.com/v1/tracks/0FE9t6xYkqWXU2ahLh6D8X',
#     'id': '0FE9t6xYkqWXU2ahLh6D8X',
#     'is_local': False,
#     'name': 'Shape of You',
#     'popularity': 67,
#     'preview_url': 'https://p.scdn.co/mp3-preview/09e92af512355474ccf074988ea208ce6eb90a2b?cid=c81e754dc0e94ee5b3b50507cf436533',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0FE9t6xYkqWXU2ahLh6D8X'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2022-04-05T01:51:41Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/dariuscrowd'},
#     'href': 'https://api.spotify.com/v1/users/dariuscrowd',
#     'id': 'dariuscrowd',
#     'type': 'user',
#     'uri': 'spotify:user:dariuscrowd'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#        'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#        'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#        'name': 'The Weeknd',
#        'type': 'artist',
#        'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#      'available_markets': ['KR'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2ZfHkwHuoAZrlz7RMj0PDz'},
#      'href': 'https://api.spotify.com/v1/albums/2ZfHkwHuoAZrlz7RMj0PDz',
#      'id': '2ZfHkwHuoAZrlz7RMj0PDz',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273c464fabb4e51b72d657f779a',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02c464fabb4e51b72d657f779a',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851c464fabb4e51b72d657f779a',
#        'width': 64}],
#      'name': 'Blinding Lights',
#      'release_date': '2019-11-29',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:2ZfHkwHuoAZrlz7RMj0PDz'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#       'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#       'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#       'name': 'The Weeknd',
#       'type': 'artist',
#       'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#     'available_markets': ['KR'],
#     'disc_number': 1,
#     'duration_ms': 201573,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUG11904206'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0sf12qNH5qcw8qpgymFOqD'},
#     'href': 'https://api.spotify.com/v1/tracks/0sf12qNH5qcw8qpgymFOqD',
#     'id': '0sf12qNH5qcw8qpgymFOqD',
#     'is_local': False,
#     'name': 'Blinding Lights',
#     'popularity': 17,
#     'preview_url': None,
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0sf12qNH5qcw8qpgymFOqD'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2022-04-05T01:51:41Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/dariuscrowd'},
#     'href': 'https://api.spotify.com/v1/users/dariuscrowd',
#     'id': 'dariuscrowd',
#     'type': 'user',
#     'uri': 'spotify:user:dariuscrowd'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2NjfBq1NflQcKSeiDooVjY'},
#        'href': 'https://api.spotify.com/v1/artists/2NjfBq1NflQcKSeiDooVjY',
#        'id': '2NjfBq1NflQcKSeiDooVjY',
#        'name': 'Tones And I',
#        'type': 'artist',
#        'uri': 'spotify:artist:2NjfBq1NflQcKSeiDooVjY'}],
#      'available_markets': ['AU', 'NZ'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/31IDBea3eEs57a0joX6TjN'},
#      'href': 'https://api.spotify.com/v1/albums/31IDBea3eEs57a0joX6TjN',
#      'id': '31IDBea3eEs57a0joX6TjN',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27338802659d156935ada63c9e3',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0238802659d156935ada63c9e3',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485138802659d156935ada63c9e3',
#        'width': 64}],
#      'name': 'Dance Monkey',
#      'release_date': '2019-05-10',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:31IDBea3eEs57a0joX6TjN'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2NjfBq1NflQcKSeiDooVjY'},
#       'href': 'https://api.spotify.com/v1/artists/2NjfBq1NflQcKSeiDooVjY',
#       'id': '2NjfBq1NflQcKSeiDooVjY',
#       'name': 'Tones And I',
#       'type': 'artist',
#       'uri': 'spotify:artist:2NjfBq1NflQcKSeiDooVjY'}],
#     'available_markets': ['AU', 'NZ'],
#     'disc_number': 1,
#     'duration_ms': 209754,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'QZES71982312'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1rgnBhdG2JDFTbYkYRZAku'},
#     'href': 'https://api.spotify.com/v1/tracks/1rgnBhdG2JDFTbYkYRZAku',
#     'id': '1rgnBhdG2JDFTbYkYRZAku',
#     'is_local': False,
#     'name': 'Dance Monkey',
#     'popularity': 63,
#     'preview_url': 'https://p.scdn.co/mp3-preview/e8ecb833d4bf0348b693e2b47c81494dfbfb607f?cid=c81e754dc0e94ee5b3b50507cf436533',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:1rgnBhdG2JDFTbYkYRZAku'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2022-04-05T01:51:41Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/dariuscrowd'},
#     'href': 'https://api.spotify.com/v1/users/dariuscrowd',
#     'id': 'dariuscrowd',
#     'type': 'user',
#     'uri': 'spotify:user:dariuscrowd'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/246dkjvS1zLTtiykXe5h60'},
#        'href': 'https://api.spotify.com/v1/artists/246dkjvS1zLTtiykXe5h60',
#        'id': '246dkjvS1zLTtiykXe5h60',
#        'name': 'Post Malone',
#        'type': 'artist',
#        'uri': 'spotify:artist:246dkjvS1zLTtiykXe5h60'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1YCRXKLDRB0UnbrFUJ4F6e'},
#      'href': 'https://api.spotify.com/v1/albums/1YCRXKLDRB0UnbrFUJ4F6e',
#      'id': '1YCRXKLDRB0UnbrFUJ4F6e',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d3884f06c92d826ecd87a319',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d3884f06c92d826ecd87a319',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851d3884f06c92d826ecd87a319',
#        'width': 64}],
#      'name': 'rockstar',
#      'release_date': '2017-09-15',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:1YCRXKLDRB0UnbrFUJ4F6e'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/246dkjvS1zLTtiykXe5h60'},
#       'href': 'https://api.spotify.com/v1/artists/246dkjvS1zLTtiykXe5h60',
#       'id': '246dkjvS1zLTtiykXe5h60',
#       'name': 'Post Malone',
#       'type': 'artist',
#       'uri': 'spotify:artist:246dkjvS1zLTtiykXe5h60'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1URnnhqYAYcrqrcwql10ft'},
#       'href': 'https://api.spotify.com/v1/artists/1URnnhqYAYcrqrcwql10ft',
#       'id': '1URnnhqYAYcrqrcwql10ft',
#       'name': '21 Savage',
#       'type': 'artist',
#       'uri': 'spotify:artist:1URnnhqYAYcrqrcwql10ft'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 218320,
#     'episode': False,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUM71710087'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1OmcAT5Y8eg5bUPv9qJT4R'},
#     'href': 'https://api.spotify.com/v1/tracks/1OmcAT5Y8eg5bUPv9qJT4R',
#     'id': '1OmcAT5Y8eg5bUPv9qJT4R',
#     'is_local': False,
#     'name': 'rockstar',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:1OmcAT5Y8eg5bUPv9qJT4R'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2022-04-05T01:51:41Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/dariuscrowd'},
#     'href': 'https://api.spotify.com/v1/users/dariuscrowd',
#     'id': 'dariuscrowd',
#     'type': 'user',
#     'uri': 'spotify:user:dariuscrowd'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4GNC7GD6oZMSxPGyXy4MNB'},
#        'href': 'https://api.spotify.com/v1/artists/4GNC7GD6oZMSxPGyXy4MNB',
#        'id': '4GNC7GD6oZMSxPGyXy4MNB',
#        'name': 'Lewis Capaldi',
#        'type': 'artist',
#        'uri': 'spotify:artist:4GNC7GD6oZMSxPGyXy4MNB'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5658aM19fA3JVwTK6eQX70'},
#      'href': 'https://api.spotify.com/v1/albums/5658aM19fA3JVwTK6eQX70',
#      'id': '5658aM19fA3JVwTK6eQX70',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273fc2101e6889d6ce9025f85f2',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02fc2101e6889d6ce9025f85f2',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851fc2101e6889d6ce9025f85f2',
#        'width': 64}],
#      'name': 'Divinely Uninspired To A Hellish Extent',
#      'release_date': '2019-05-17',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:5658aM19fA3JVwTK6eQX70'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4GNC7GD6oZMSxPGyXy4MNB'},
#       'href': 'https://api.spotify.com/v1/artists/4GNC7GD6oZMSxPGyXy4MNB',
#       'id': '4GNC7GD6oZMSxPGyXy4MNB',
#       'name': 'Lewis Capaldi',
#       'type': 'artist',
#       'uri': 'spotify:artist:4GNC7GD6oZMSxPGyXy4MNB'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 182160,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'DEUM71807062'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7qEHsqek33rTcFNT9PFqLf'},
#     'href': 'https://api.spotify.com/v1/tracks/7qEHsqek33rTcFNT9PFqLf',
#     'id': '7qEHsqek33rTcFNT9PFqLf',
#     'is_local': False,
#     'name': 'Someone You Loved',
#     'popularity': 87,
#     'preview_url': None,
#     'track': True,
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:7qEHsqek33rTcFNT9PFqLf'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2022-04-05T01:51:41Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/dariuscrowd'},
#     'href': 'https://api.spotify.com/v1/users/dariuscrowd',
#     'id': 'dariuscrowd',
#     'type': 'user',
#     'uri': 'spotify:user:dariuscrowd'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/246dkjvS1zLTtiykXe5h60'},
#        'href': 'https://api.spotify.com/v1/artists/246dkjvS1zLTtiykXe5h60',
#        'id': '246dkjvS1zLTtiykXe5h60',
#        'name': 'Post Malone',
#        'type': 'artist',
#        'uri': 'spotify:artist:246dkjvS1zLTtiykXe5h60'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/1zNqQNIdeOUZHb8zbZRFMX'},
#        'href': 'https://api.spotify.com/v1/artists/1zNqQNIdeOUZHb8zbZRFMX',
#        'id': '1zNqQNIdeOUZHb8zbZRFMX',
#        'name': 'Swae Lee',
#        'type': 'artist',
#        'uri': 'spotify:artist:1zNqQNIdeOUZHb8zbZRFMX'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/47LpgGVshd0tbFSbm9tTLb'},
#      'href': 'https://api.spotify.com/v1/albums/47LpgGVshd0tbFSbm9tTLb',
#      'id': '47LpgGVshd0tbFSbm9tTLb',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273ef376d3257503f734de0eefc',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02ef376d3257503f734de0eefc',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851ef376d3257503f734de0eefc',
#        'width': 64}],
#      'name': 'Sunflower (Spider-Man: Into the Spider-Verse)',
#      'release_date': '2018-10-18',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:47LpgGVshd0tbFSbm9tTLb'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/246dkjvS1zLTtiykXe5h60'},
#       'href': 'https://api.spotify.com/v1/artists/246dkjvS1zLTtiykXe5h60',
#       'id': '246dkjvS1zLTtiykXe5h60',
#       'name': 'Post Malone',
#       'type': 'artist',
#       'uri': 'spotify:artist:246dkjvS1zLTtiykXe5h60'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1zNqQNIdeOUZHb8zbZRFMX'},
#       'href': 'https://api.spotify.com/v1/artists/1zNqQNIdeOUZHb8zbZRFMX',
#       'id': '1zNqQNIdeOUZHb8zbZRFMX',
#       'name': 'Swae Lee',
#       'type': 'artist',
#       'uri': 'spotify:artist:1zNqQNIdeOUZHb8zbZRFMX'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 158053,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71814888'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1A6OTy97kk0mMdm78rHsm8'},
#     'href': 'https://api.spotify.com/v1/tracks/1A6OTy97kk0mMdm78rHsm8',
#     'id': '1A6OTy97kk0mMdm78rHsm8',
#     'is_local': False,
#     'name': 'Sunflower - Spider-Man: Into the Spider-Verse',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:1A6OTy97kk0mMdm78rHsm8'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2022-04-05T01:51:41Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/dariuscrowd'},
#     'href': 'https://api.spotify.com/v1/users/dariuscrowd',
#     'id': 'dariuscrowd',
#     'type': 'user',
#     'uri': 'spotify:user:dariuscrowd'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3TVXtAsR1Inumwj472S9r4'},
#        'href': 'https://api.spotify.com/v1/artists/3TVXtAsR1Inumwj472S9r4',
#        'id': '3TVXtAsR1Inumwj472S9r4',
#        'name': 'Drake',
#        'type': 'artist',
#        'uri': 'spotify:artist:3TVXtAsR1Inumwj472S9r4'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/05FOcj5Cygu51XbAmlJd2k'},
#      'href': 'https://api.spotify.com/v1/albums/05FOcj5Cygu51XbAmlJd2k',
#      'id': '05FOcj5Cygu51XbAmlJd2k',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2739f38087c2900d53c2e81030a',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e029f38087c2900d53c2e81030a',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048519f38087c2900d53c2e81030a',
#        'width': 64}],
#      'name': 'One Dance',
#      'release_date': '2016-04-05',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:05FOcj5Cygu51XbAmlJd2k'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3TVXtAsR1Inumwj472S9r4'},
#       'href': 'https://api.spotify.com/v1/artists/3TVXtAsR1Inumwj472S9r4',
#       'id': '3TVXtAsR1Inumwj472S9r4',
#       'name': 'Drake',
#       'type': 'artist',
#       'uri': 'spotify:artist:3TVXtAsR1Inumwj472S9r4'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3tVQdUvClmAT7URs9V3rsp'},
#       'href': 'https://api.spotify.com/v1/artists/3tVQdUvClmAT7URs9V3rsp',
#       'id': '3tVQdUvClmAT7URs9V3rsp',
#       'name': 'Wizkid',
#       'type': 'artist',
#       'uri': 'spotify:artist:3tVQdUvClmAT7URs9V3rsp'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/77DAFfvm3O9zT5dIoG0eIO'},
#       'href': 'https://api.spotify.com/v1/artists/77DAFfvm3O9zT5dIoG0eIO',
#       'id': '77DAFfvm3O9zT5dIoG0eIO',
#       'name': 'Kyla',
#       'type': 'artist',
#       'uri': 'spotify:artist:77DAFfvm3O9zT5dIoG0eIO'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 173974,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USCM51600028'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0JoaFxLgrqbWutREzcZBzS'},
#     'href': 'https://api.spotify.com/v1/tracks/0JoaFxLgrqbWutREzcZBzS',
#     'id': '0JoaFxLgrqbWutREzcZBzS',
#     'is_local': False,
#     'name': 'One Dance',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0JoaFxLgrqbWutREzcZBzS'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2022-04-05T01:51:41Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/dariuscrowd'},
#     'href': 'https://api.spotify.com/v1/users/dariuscrowd',
#     'id': 'dariuscrowd',
#     'type': 'user',
#     'uri': 'spotify:user:dariuscrowd'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/69GGBxA162lTqCwzJG5jLp'},
#        'href': 'https://api.spotify.com/v1/artists/69GGBxA162lTqCwzJG5jLp',
#        'id': '69GGBxA162lTqCwzJG5jLp',
#        'name': 'The Chainsmokers',
#        'type': 'artist',
#        'uri': 'spotify:artist:69GGBxA162lTqCwzJG5jLp'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/26VFTg2z8YR0cCuwLzESi2'},
#        'href': 'https://api.spotify.com/v1/artists/26VFTg2z8YR0cCuwLzESi2',
#        'id': '26VFTg2z8YR0cCuwLzESi2',
#        'name': 'Halsey',
#        'type': 'artist',
#        'uri': 'spotify:artist:26VFTg2z8YR0cCuwLzESi2'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0rSLgV8p5FzfnqlEk4GzxE'},
#      'href': 'https://api.spotify.com/v1/albums/0rSLgV8p5FzfnqlEk4GzxE',
#      'id': '0rSLgV8p5FzfnqlEk4GzxE',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273495ce6da9aeb159e94eaa453',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02495ce6da9aeb159e94eaa453',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851495ce6da9aeb159e94eaa453',
#        'width': 64}],
#      'name': 'Closer',
#      'release_date': '2016-07-29',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:0rSLgV8p5FzfnqlEk4GzxE'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/69GGBxA162lTqCwzJG5jLp'},
#       'href': 'https://api.spotify.com/v1/artists/69GGBxA162lTqCwzJG5jLp',
#       'id': '69GGBxA162lTqCwzJG5jLp',
#       'name': 'The Chainsmokers',
#       'type': 'artist',
#       'uri': 'spotify:artist:69GGBxA162lTqCwzJG5jLp'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/26VFTg2z8YR0cCuwLzESi2'},
#       'href': 'https://api.spotify.com/v1/artists/26VFTg2z8YR0cCuwLzESi2',
#       'id': '26VFTg2z8YR0cCuwLzESi2',
#       'name': 'Halsey',
#       'type': 'artist',
#       'uri': 'spotify:artist:26VFTg2z8YR0cCuwLzESi2'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 244960,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USQX91601347'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7BKLCZ1jbUBVqRi2FVlTVw'},
#     'href': 'https://api.spotify.com/v1/tracks/7BKLCZ1jbUBVqRi2FVlTVw',
#     'id': '7BKLCZ1jbUBVqRi2FVlTVw',
#     'is_local': False,
#     'name': 'Closer',
#     'popularity': 84,
#     'preview_url': 'https://p.scdn.co/mp3-preview/aacaac1614505dbb3eb2045a31f2c0cb70e7aa59?cid=c81e754dc0e94ee5b3b50507cf436533',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:7BKLCZ1jbUBVqRi2FVlTVw'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2022-04-05T01:51:41Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/dariuscrowd'},
#     'href': 'https://api.spotify.com/v1/users/dariuscrowd',
#     'id': 'dariuscrowd',
#     'type': 'user',
#     'uri': 'spotify:user:dariuscrowd'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#        'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#        'id': '53XhwfbYqKCa1cC15pYq2q',
#        'name': 'Imagine Dragons',
#        'type': 'artist',
#        'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3KzCJaaRVza9FnSsqtAFeO'},
#      'href': 'https://api.spotify.com/v1/albums/3KzCJaaRVza9FnSsqtAFeO',
#      'id': '3KzCJaaRVza9FnSsqtAFeO',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273156aeddf54ed40b1d9d30c9f',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02156aeddf54ed40b1d9d30c9f',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851156aeddf54ed40b1d9d30c9f',
#        'width': 64}],
#      'name': 'Believer',
#      'release_date': '2017-01-31',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:3KzCJaaRVza9FnSsqtAFeO'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#       'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#       'id': '53XhwfbYqKCa1cC15pYq2q',
#       'name': 'Imagine Dragons',
#       'type': 'artist',
#       'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 203782,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71700626'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6VRghJeP6I0w1KxkdWFfIh'},
#     'href': 'https://api.spotify.com/v1/tracks/6VRghJeP6I0w1KxkdWFfIh',
#     'id': '6VRghJeP6I0w1KxkdWFfIh',
#     'is_local': False,
#     'name': 'Believer',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6VRghJeP6I0w1KxkdWFfIh'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2022-04-05T01:51:41Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/dariuscrowd'},
#     'href': 'https://api.spotify.com/v1/users/dariuscrowd',
#     'id': 'dariuscrowd',
#     'type': 'user',
#     'uri': 'spotify:user:dariuscrowd'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7n2wHs1TKAczGzO7Dd2rGr'},
#        'href': 'https://api.spotify.com/v1/artists/7n2wHs1TKAczGzO7Dd2rGr',
#        'id': '7n2wHs1TKAczGzO7Dd2rGr',
#        'name': 'Shawn Mendes',
#        'type': 'artist',
#        'uri': 'spotify:artist:7n2wHs1TKAczGzO7Dd2rGr'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/4nDoRrQiYLoBzwC5BhVJzF'},
#        'href': 'https://api.spotify.com/v1/artists/4nDoRrQiYLoBzwC5BhVJzF',
#        'id': '4nDoRrQiYLoBzwC5BhVJzF',
#        'name': 'Camila Cabello',
#        'type': 'artist',
#        'uri': 'spotify:artist:4nDoRrQiYLoBzwC5BhVJzF'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2ZaX1FdZCwchXl1QZiD4O4'},
#      'href': 'https://api.spotify.com/v1/albums/2ZaX1FdZCwchXl1QZiD4O4',
#      'id': '2ZaX1FdZCwchXl1QZiD4O4',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273e6095c382c2853667c1623eb',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02e6095c382c2853667c1623eb',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851e6095c382c2853667c1623eb',
#        'width': 64}],
#      'name': 'Señorita',
#      'release_date': '2019-06-21',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:2ZaX1FdZCwchXl1QZiD4O4'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7n2wHs1TKAczGzO7Dd2rGr'},
#       'href': 'https://api.spotify.com/v1/artists/7n2wHs1TKAczGzO7Dd2rGr',
#       'id': '7n2wHs1TKAczGzO7Dd2rGr',
#       'name': 'Shawn Mendes',
#       'type': 'artist',
#       'uri': 'spotify:artist:7n2wHs1TKAczGzO7Dd2rGr'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4nDoRrQiYLoBzwC5BhVJzF'},
#       'href': 'https://api.spotify.com/v1/artists/4nDoRrQiYLoBzwC5BhVJzF',
#       'id': '4nDoRrQiYLoBzwC5BhVJzF',
#       'name': 'Camila Cabello',
#       'type': 'artist',
#       'uri': 'spotify:artist:4nDoRrQiYLoBzwC5BhVJzF'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 190960,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71911283'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0TK2YIli7K1leLovkQiNik'},
#     'href': 'https://api.spotify.com/v1/tracks/0TK2YIli7K1leLovkQiNik',
#     'id': '0TK2YIli7K1leLovkQiNik',
#     'is_local': False,
#     'name': 'Señorita',
#     'popularity': 79,
#     'preview_url': None,
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0TK2YIli7K1leLovkQiNik'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2022-04-05T01:51:41Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/dariuscrowd'},
#     'href': 'https://api.spotify.com/v1/users/dariuscrowd',
#     'id': 'dariuscrowd',
#     'type': 'user',
#     'uri': 'spotify:user:dariuscrowd'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'},
#        'href': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V',
#        'id': '6eUKZXaKkcviH0Ku9w2n3V',
#        'name': 'Ed Sheeran',
#        'type': 'artist',
#        'uri': 'spotify:artist:6eUKZXaKkcviH0Ku9w2n3V'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3T4tUhGYeRNVUGevb0wThu'},
#      'href': 'https://api.spotify.com/v1/albums/3T4tUhGYeRNVUGevb0wThu',
#      'id': '3T4tUhGYeRNVUGevb0wThu',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273ba5db46f4b838ef6027e6f96',
# ...
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'IE',
#      'IL',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'KE',
#      'KG',
#      'KI',
#      'KM',
#      'KN',
#      'KW',
#      'KZ',
#      'LB',
#      'LC',
#      'LI',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PK',
#      'PL',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 235493,
#     'episode': False,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUM71410340'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2iuZJX9X9P0GKaE93xcPjk'},
#     'href': 'https://api.spotify.com/v1/tracks/2iuZJX9X9P0GKaE93xcPjk',
#     'id': '2iuZJX9X9P0GKaE93xcPjk',
#     'is_local': False,
#     'name': 'Sugar',
#     'popularity': 80,
#     'preview_url': None,
#     'track': True,
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:2iuZJX9X9P0GKaE93xcPjk'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2022-04-05T01:51:41Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/dariuscrowd'},
#     'href': 'https://api.spotify.com/v1/users/dariuscrowd',
#     'id': 'dariuscrowd',
#     'type': 'user',
#     'uri': 'spotify:user:dariuscrowd'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Rl15oVamLq7FbSb0NNBNy'},
#        'href': 'https://api.spotify.com/v1/artists/5Rl15oVamLq7FbSb0NNBNy',
#        'id': '5Rl15oVamLq7FbSb0NNBNy',
#        'name': '5 Seconds of Summer',
#        'type': 'artist',
#        'uri': 'spotify:artist:5Rl15oVamLq7FbSb0NNBNy'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/16Qs4jnIyXe7jprnMNRddy'},
#      'href': 'https://api.spotify.com/v1/albums/16Qs4jnIyXe7jprnMNRddy',
#      'id': '16Qs4jnIyXe7jprnMNRddy',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273240353172d4b7f2feb8a3e2c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02240353172d4b7f2feb8a3e2c',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851240353172d4b7f2feb8a3e2c',
#        'width': 64}],
#      'name': 'Youngblood',
#      'release_date': '2018-04-12',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:16Qs4jnIyXe7jprnMNRddy'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Rl15oVamLq7FbSb0NNBNy'},
#       'href': 'https://api.spotify.com/v1/artists/5Rl15oVamLq7FbSb0NNBNy',
#       'id': '5Rl15oVamLq7FbSb0NNBNy',
#       'name': '5 Seconds of Summer',
#       'type': 'artist',
#       'uri': 'spotify:artist:5Rl15oVamLq7FbSb0NNBNy'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 203417,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBUM71800366'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/55S2PQgSMYAhgoTCcGCDfw'},
#     'href': 'https://api.spotify.com/v1/tracks/55S2PQgSMYAhgoTCcGCDfw',
#     'id': '55S2PQgSMYAhgoTCcGCDfw',
#     'is_local': False,
#     'name': 'Youngblood',
#     'popularity': 68,
#     'preview_url': None,
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:55S2PQgSMYAhgoTCcGCDfw'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2022-04-05T01:51:41Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/dariuscrowd'},
#     'href': 'https://api.spotify.com/v1/users/dariuscrowd',
#     'id': 'dariuscrowd',
#     'type': 'user',
#     'uri': 'spotify:user:dariuscrowd'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/31TPClRtHm23RisEBtV3X7'},
#        'href': 'https://api.spotify.com/v1/artists/31TPClRtHm23RisEBtV3X7',
#        'id': '31TPClRtHm23RisEBtV3X7',
#        'name': 'Justin Timberlake',
#        'type': 'artist',
#        'uri': 'spotify:artist:31TPClRtHm23RisEBtV3X7'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/40LbnfieVTWtHrK24WQeEB'},
#      'href': 'https://api.spotify.com/v1/albums/40LbnfieVTWtHrK24WQeEB',
#      'id': '40LbnfieVTWtHrK24WQeEB',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273ef37416970812293c08e8a78',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02ef37416970812293c08e8a78',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851ef37416970812293c08e8a78',
#        'width': 64}],
#      'name': 'CAN\'T STOP THE FEELING! (from DreamWorks Animation\'s "TROLLS")',
#      'release_date': '2016-05-06',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:40LbnfieVTWtHrK24WQeEB'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/31TPClRtHm23RisEBtV3X7'},
#       'href': 'https://api.spotify.com/v1/artists/31TPClRtHm23RisEBtV3X7',
#       'id': '31TPClRtHm23RisEBtV3X7',
#       'name': 'Justin Timberlake',
#       'type': 'artist',
#       'uri': 'spotify:artist:31TPClRtHm23RisEBtV3X7'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 236001,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USRC11600876'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6JV2JOEocMgcZxYSZelKcc'},
#     'href': 'https://api.spotify.com/v1/tracks/6JV2JOEocMgcZxYSZelKcc',
#     'id': '6JV2JOEocMgcZxYSZelKcc',
#     'is_local': False,
#     'name': 'CAN\'T STOP THE FEELING! (from DreamWorks Animation\'s "TROLLS")',
#     'popularity': 77,
#     'preview_url': 'https://p.scdn.co/mp3-preview/092b2d551331460c5890e5fdd55eab9bde9c70b8?cid=c81e754dc0e94ee5b3b50507cf436533',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6JV2JOEocMgcZxYSZelKcc'},
#    'video_thumbnail': {'url': None}}],
#  'limit': 100,
#  'next': 'https://api.spotify.com/v1/playlists/3RWRqUa3ghwX7ZeXWOReYn/tracks?offset=100&limit=100&additional_types=track',
#  'offset': 0,
#  'previous': None,
#  'total': 509}

# %%
# Check how many tracks are in the response
len(playlist['items'])
# Out:
# 100

# %% [markdown]
# Note that only 100 tracks were retrieved, due to the API retrieval limit of 100.
# Use loop to make multiple API calls to get all tracks.

# %%
results = sp.playlist_tracks(playlist_uri)

# initialise list with first 100 results in playlist
playlist = results['items']

# playlist['next'] field indicates whether there is a next page of results
# sp.next() retrieves those songs in the next page
while results['next']:
    
    # Debug - print playlist['next'] to check iterations
    # print(results['next'])
    
    # get next page of tracks
    results = sp.next(results)
    
    # add results to list
    playlist.extend(results['items'])

# %% [markdown]
# Now I should have all tracks in the playlist.

# %%
len(playlist)
# Out:
# 509

# %%
playlist[0]
# Out:
# {'added_at': '2022-04-05T01:51:41Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/dariuscrowd'},
#   'href': 'https://api.spotify.com/v1/users/dariuscrowd',
#   'id': 'dariuscrowd',
#   'type': 'user',
#   'uri': 'spotify:user:dariuscrowd'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'},
#      'href': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V',
#      'id': '6eUKZXaKkcviH0Ku9w2n3V',
#      'name': 'Ed Sheeran',
#      'type': 'artist',
#      'uri': 'spotify:artist:6eUKZXaKkcviH0Ku9w2n3V'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/7oJa8bPFKVbq4c7NswXHw8'},
#    'href': 'https://api.spotify.com/v1/albums/7oJa8bPFKVbq4c7NswXHw8',
#    'id': '7oJa8bPFKVbq4c7NswXHw8',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27383e9b06ccd219248b5301264',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0283e9b06ccd219248b5301264',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485183e9b06ccd219248b5301264',
#      'width': 64}],
#    'name': 'Shape of You',
#    'release_date': '2017-01-06',
#    'release_date_precision': 'day',
#    'total_tracks': 1,
#    'type': 'album',
#    'uri': 'spotify:album:7oJa8bPFKVbq4c7NswXHw8'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'},
#     'href': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V',
#     'id': '6eUKZXaKkcviH0Ku9w2n3V',
#     'name': 'Ed Sheeran',
#     'type': 'artist',
#     'uri': 'spotify:artist:6eUKZXaKkcviH0Ku9w2n3V'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CD',
#    'CG',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IL',
#    'IN',
#    'IQ',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'LY',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TJ',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VE',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'disc_number': 1,
#   'duration_ms': 233712,
#   'episode': False,
#   'explicit': False,
#   'external_ids': {'isrc': 'GBAHS1600463'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/0FE9t6xYkqWXU2ahLh6D8X'},
#   'href': 'https://api.spotify.com/v1/tracks/0FE9t6xYkqWXU2ahLh6D8X',
#   'id': '0FE9t6xYkqWXU2ahLh6D8X',
#   'is_local': False,
#   'name': 'Shape of You',
#   'popularity': 67,
#   'preview_url': 'https://p.scdn.co/mp3-preview/09e92af512355474ccf074988ea208ce6eb90a2b?cid=c81e754dc0e94ee5b3b50507cf436533',
#   'track': True,
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:0FE9t6xYkqWXU2ahLh6D8X'},
#  'video_thumbnail': {'url': None}}

# %% [markdown]
# For every track in playlist, I want to get the following data.
#
# - ID
# - Name
# - Popularity
# - Album
# - Release Date
# - Duration
# - Explicit
# - Artist name
#
# Additional data (retrieved via other APIs).
# - Artist popularity
# - Artist genres
# - Audio features
#
#
# Audio features API provides interesting audio metrics of a track. These will be analysed later.
#
# e.g.

# %%
sp.audio_features('spotify:track:0FE9t6xYkqWXU2ahLh6D8X')
# Out:
# [{'danceability': 0.825,
#   'energy': 0.652,
#   'key': 1,
#   'loudness': -3.183,
#   'mode': 0,
#   'speechiness': 0.0802,
#   'acousticness': 0.581,
#   'instrumentalness': 0,
#   'liveness': 0.0931,
#   'valence': 0.931,
#   'tempo': 95.977,
#   'type': 'audio_features',
#   'id': '0FE9t6xYkqWXU2ahLh6D8X',
#   'uri': 'spotify:track:0FE9t6xYkqWXU2ahLh6D8X',
#   'track_href': 'https://api.spotify.com/v1/tracks/0FE9t6xYkqWXU2ahLh6D8X',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0FE9t6xYkqWXU2ahLh6D8X',
#   'duration_ms': 233713,
#   'time_signature': 4}]

# %% [markdown]
# Following function takes the raw response data and flesh out the fields I need.
# This also **enriches** the output by getting additional data from artist and audio feature APIs.
#
# Input - Dictionary, raw data of a track
# Output - Dictionary, formatted data of the input track

# %%
def enrich_track(item: dict):
    
    # call artist API to get additional artist info
    artist = sp.artist(item["track"]["artists"][0]["uri"])
    
    # track and artist data
    track = {
        "track_id": item["track"]["id"],
        "track_name": item["track"]["name"],
        "track_pop": item["track"]["popularity"],
        "album": item["track"]["album"]["name"],
        "release_date": item["track"]["album"]["release_date"],
        "duration": item["track"]["duration_ms"],
        "explicit": item["track"]["explicit"],
        "artist_name": item["track"]["artists"][0]["name"],
        "artist_pop": artist["popularity"],
        "artist_genres": artist["genres"]
    }
    
    # call audio features API to get audio analysis of track
    audio = sp.audio_features(item["track"]["uri"])[0]
    
    # update track with audio features data
    track.update(audio)
    
    # return the complete track data as dictionary
    return track

# %% [markdown]
# Now call the enrich_track function on every track in playlist, appending them into a single list.

# %%
# enrich every song in the playlist
# save as a list of dictionaries - to easily convert to dataframe later
tracks = [enrich_track(song) for song in playlist]

# %%
tracks
# Out:
# [{'track_id': '0FE9t6xYkqWXU2ahLh6D8X',
#   'track_name': 'Shape of You',
#   'track_pop': 67,
#   'album': 'Shape of You',
#   'release_date': '2017-01-06',
#   'duration': 233712,
#   'explicit': False,
#   'artist_name': 'Ed Sheeran',
#   'artist_pop': 89,
#   'artist_genres': ['pop', 'uk pop'],
#   'danceability': 0.825,
#   'energy': 0.652,
#   'key': 1,
#   'loudness': -3.183,
#   'mode': 0,
#   'speechiness': 0.0802,
#   'acousticness': 0.581,
#   'instrumentalness': 0,
#   'liveness': 0.0931,
#   'valence': 0.931,
#   'tempo': 95.977,
#   'type': 'audio_features',
#   'id': '0FE9t6xYkqWXU2ahLh6D8X',
#   'uri': 'spotify:track:0FE9t6xYkqWXU2ahLh6D8X',
#   'track_href': 'https://api.spotify.com/v1/tracks/0FE9t6xYkqWXU2ahLh6D8X',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0FE9t6xYkqWXU2ahLh6D8X',
#   'duration_ms': 233713,
#   'time_signature': 4},
#  {'track_id': '0sf12qNH5qcw8qpgymFOqD',
#   'track_name': 'Blinding Lights',
#   'track_pop': 17,
#   'album': 'Blinding Lights',
#   'release_date': '2019-11-29',
#   'duration': 201573,
#   'explicit': False,
#   'artist_name': 'The Weeknd',
#   'artist_pop': 93,
#   'artist_genres': ['canadian contemporary r&b', 'canadian pop', 'pop'],
#   'danceability': 0.513,
#   'energy': 0.796,
#   'key': 1,
#   'loudness': -4.075,
#   'mode': 1,
#   'speechiness': 0.0629,
#   'acousticness': 0.00147,
#   'instrumentalness': 0.000209,
#   'liveness': 0.0938,
#   'valence': 0.345,
#   'tempo': 171.017,
#   'type': 'audio_features',
#   'id': '0sf12qNH5qcw8qpgymFOqD',
#   'uri': 'spotify:track:0sf12qNH5qcw8qpgymFOqD',
#   'track_href': 'https://api.spotify.com/v1/tracks/0sf12qNH5qcw8qpgymFOqD',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0sf12qNH5qcw8qpgymFOqD',
#   'duration_ms': 201573,
#   'time_signature': 4},
#  {'track_id': '1rgnBhdG2JDFTbYkYRZAku',
#   'track_name': 'Dance Monkey',
#   'track_pop': 63,
#   'album': 'Dance Monkey',
#   'release_date': '2019-05-10',
#   'duration': 209754,
#   'explicit': False,
#   'artist_name': 'Tones And I',
#   'artist_pop': 70,
#   'artist_genres': ['australian pop', 'pop'],
#   'danceability': 0.826,
#   'energy': 0.593,
#   'key': 6,
#   'loudness': -6.401,
#   'mode': 0,
#   'speechiness': 0.0976,
#   'acousticness': 0.688,
#   'instrumentalness': 0.000161,
#   'liveness': 0.17,
#   'valence': 0.541,
#   'tempo': 98.083,
#   'type': 'audio_features',
#   'id': '1rgnBhdG2JDFTbYkYRZAku',
#   'uri': 'spotify:track:1rgnBhdG2JDFTbYkYRZAku',
#   'track_href': 'https://api.spotify.com/v1/tracks/1rgnBhdG2JDFTbYkYRZAku',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1rgnBhdG2JDFTbYkYRZAku',
#   'duration_ms': 209755,
#   'time_signature': 4},
#  {'track_id': '1OmcAT5Y8eg5bUPv9qJT4R',
#   'track_name': 'rockstar',
#   'track_pop': 0,
#   'album': 'rockstar',
#   'release_date': '2017-09-15',
#   'duration': 218320,
#   'explicit': True,
#   'artist_name': 'Post Malone',
#   'artist_pop': 87,
#   'artist_genres': ['dfw rap', 'melodic rap', 'rap'],
#   'danceability': 0.58,
#   'energy': 0.531,
#   'key': 5,
#   'loudness': -6.631,
#   'mode': 0,
#   'speechiness': 0.0776,
#   'acousticness': 0.128,
#   'instrumentalness': 0.000127,
#   'liveness': 0.143,
#   'valence': 0.141,
#   'tempo': 159.786,
#   'type': 'audio_features',
#   'id': '1OmcAT5Y8eg5bUPv9qJT4R',
#   'uri': 'spotify:track:1OmcAT5Y8eg5bUPv9qJT4R',
#   'track_href': 'https://api.spotify.com/v1/tracks/1OmcAT5Y8eg5bUPv9qJT4R',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1OmcAT5Y8eg5bUPv9qJT4R',
#   'duration_ms': 218320,
#   'time_signature': 4},
#  {'track_id': '7qEHsqek33rTcFNT9PFqLf',
#   'track_name': 'Someone You Loved',
#   'track_pop': 87,
#   'album': 'Divinely Uninspired To A Hellish Extent',
#   'release_date': '2019-05-17',
#   'duration': 182160,
#   'explicit': False,
#   'artist_name': 'Lewis Capaldi',
#   'artist_pop': 80,
#   'artist_genres': ['pop', 'uk pop'],
#   'danceability': 0.501,
#   'energy': 0.405,
#   'key': 1,
#   'loudness': -5.679,
#   'mode': 1,
#   'speechiness': 0.0319,
#   'acousticness': 0.751,
#   'instrumentalness': 0,
#   'liveness': 0.105,
#   'valence': 0.446,
#   'tempo': 109.891,
#   'type': 'audio_features',
#   'id': '7qEHsqek33rTcFNT9PFqLf',
#   'uri': 'spotify:track:7qEHsqek33rTcFNT9PFqLf',
#   'track_href': 'https://api.spotify.com/v1/tracks/7qEHsqek33rTcFNT9PFqLf',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7qEHsqek33rTcFNT9PFqLf',
#   'duration_ms': 182161,
#   'time_signature': 4},
#  {'track_id': '1A6OTy97kk0mMdm78rHsm8',
#   'track_name': 'Sunflower - Spider-Man: Into the Spider-Verse',
#   'track_pop': 0,
#   'album': 'Sunflower (Spider-Man: Into the Spider-Verse)',
#   'release_date': '2018-10-18',
#   'duration': 158053,
#   'explicit': False,
#   'artist_name': 'Post Malone',
#   'artist_pop': 87,
#   'artist_genres': ['dfw rap', 'melodic rap', 'rap'],
#   'danceability': 0.753,
#   'energy': 0.498,
#   'key': 2,
#   'loudness': -5.61,
#   'mode': 1,
#   'speechiness': 0.0504,
#   'acousticness': 0.551,
#   'instrumentalness': 0,
#   'liveness': 0.0706,
#   'valence': 0.927,
#   'tempo': 89.95,
#   'type': 'audio_features',
#   'id': '1A6OTy97kk0mMdm78rHsm8',
#   'uri': 'spotify:track:1A6OTy97kk0mMdm78rHsm8',
#   'track_href': 'https://api.spotify.com/v1/tracks/1A6OTy97kk0mMdm78rHsm8',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1A6OTy97kk0mMdm78rHsm8',
#   'duration_ms': 158053,
#   'time_signature': 4},
#  {'track_id': '0JoaFxLgrqbWutREzcZBzS',
#   'track_name': 'One Dance',
#   'track_pop': 0,
#   'album': 'One Dance',
#   'release_date': '2016-04-05',
#   'duration': 173974,
#   'explicit': False,
#   'artist_name': 'Drake',
#   'artist_pop': 97,
#   'artist_genres': ['canadian hip hop',
#    'canadian pop',
#    'hip hop',
#    'rap',
#    'toronto rap'],
#   'danceability': 0.771,
#   'energy': 0.629,
#   'key': 1,
#   'loudness': -5.79,
#   'mode': 1,
#   'speechiness': 0.0511,
#   'acousticness': 0.00802,
#   'instrumentalness': 0.00252,
#   'liveness': 0.356,
#   'valence': 0.362,
#   'tempo': 103.918,
#   'type': 'audio_features',
#   'id': '0JoaFxLgrqbWutREzcZBzS',
#   'uri': 'spotify:track:0JoaFxLgrqbWutREzcZBzS',
#   'track_href': 'https://api.spotify.com/v1/tracks/0JoaFxLgrqbWutREzcZBzS',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0JoaFxLgrqbWutREzcZBzS',
#   'duration_ms': 173975,
#   'time_signature': 4},
#  {'track_id': '7BKLCZ1jbUBVqRi2FVlTVw',
#   'track_name': 'Closer',
#   'track_pop': 84,
#   'album': 'Closer',
#   'release_date': '2016-07-29',
#   'duration': 244960,
#   'explicit': False,
#   'artist_name': 'The Chainsmokers',
#   'artist_pop': 79,
#   'artist_genres': ['dance pop',
#    'edm',
#    'electropop',
#    'pop',
#    'pop dance',
#    'tropical house'],
#   'danceability': 0.748,
#   'energy': 0.524,
#   'key': 8,
#   'loudness': -5.599,
#   'mode': 1,
#   'speechiness': 0.0338,
#   'acousticness': 0.414,
#   'instrumentalness': 0,
#   'liveness': 0.111,
#   'valence': 0.661,
#   'tempo': 95.01,
#   'type': 'audio_features',
#   'id': '7BKLCZ1jbUBVqRi2FVlTVw',
#   'uri': 'spotify:track:7BKLCZ1jbUBVqRi2FVlTVw',
#   'track_href': 'https://api.spotify.com/v1/tracks/7BKLCZ1jbUBVqRi2FVlTVw',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7BKLCZ1jbUBVqRi2FVlTVw',
#   'duration_ms': 244960,
#   'time_signature': 4},
#  {'track_id': '6VRghJeP6I0w1KxkdWFfIh',
#   'track_name': 'Believer',
#   'track_pop': 0,
#   'album': 'Believer',
#   'release_date': '2017-01-31',
#   'duration': 203782,
#   'explicit': False,
#   'artist_name': 'Imagine Dragons',
#   'artist_pop': 87,
#   'artist_genres': ['modern rock', 'rock'],
#   'danceability': 0.77,
#   'energy': 0.787,
#   'key': 10,
#   'loudness': -4.402,
#   'mode': 0,
#   'speechiness': 0.113,
#   'acousticness': 0.0482,
#   'instrumentalness': 0,
#   'liveness': 0.108,
#   'valence': 0.699,
#   'tempo': 125.013,
#   'type': 'audio_features',
#   'id': '6VRghJeP6I0w1KxkdWFfIh',
#   'uri': 'spotify:track:6VRghJeP6I0w1KxkdWFfIh',
#   'track_href': 'https://api.spotify.com/v1/tracks/6VRghJeP6I0w1KxkdWFfIh',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6VRghJeP6I0w1KxkdWFfIh',
#   'duration_ms': 203782,
#   'time_signature': 4},
#  {'track_id': '0TK2YIli7K1leLovkQiNik',
#   'track_name': 'Señorita',
#   'track_pop': 79,
#   'album': 'Señorita',
#   'release_date': '2019-06-21',
#   'duration': 190960,
#   'explicit': False,
#   'artist_name': 'Shawn Mendes',
#   'artist_pop': 83,
#   'artist_genres': ['canadian pop', 'dance pop', 'pop', 'viral pop'],
#   'danceability': 0.759,
#   'energy': 0.54,
#   'key': 9,
#   'loudness': -6.039,
#   'mode': 0,
#   'speechiness': 0.0287,
#   'acousticness': 0.037,
#   'instrumentalness': 0,
#   'liveness': 0.0945,
#   'valence': 0.75,
#   'tempo': 116.947,
#   'type': 'audio_features',
#   'id': '0TK2YIli7K1leLovkQiNik',
#   'uri': 'spotify:track:0TK2YIli7K1leLovkQiNik',
#   'track_href': 'https://api.spotify.com/v1/tracks/0TK2YIli7K1leLovkQiNik',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0TK2YIli7K1leLovkQiNik',
#   'duration_ms': 190960,
#   'time_signature': 4},
#  {'track_id': '0tgVpDi06FyKpA1z0VMD4v',
#   'track_name': 'Perfect',
#   'track_pop': 87,
#   'album': '÷ (Deluxe)',
#   'release_date': '2017-03-03',
#   'duration': 263400,
#   'explicit': False,
#   'artist_name': 'Ed Sheeran',
#   'artist_pop': 89,
#   'artist_genres': ['pop', 'uk pop'],
#   'danceability': 0.599,
#   'energy': 0.448,
#   'key': 8,
#   'loudness': -6.312,
#   'mode': 1,
#   'speechiness': 0.0232,
#   'acousticness': 0.163,
#   'instrumentalness': 0,
#   'liveness': 0.106,
#   'valence': 0.168,
#   'tempo': 95.05,
#   'type': 'audio_features',
#   'id': '0tgVpDi06FyKpA1z0VMD4v',
#   'uri': 'spotify:track:0tgVpDi06FyKpA1z0VMD4v',
#   'track_href': 'https://api.spotify.com/v1/tracks/0tgVpDi06FyKpA1z0VMD4v',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0tgVpDi06FyKpA1z0VMD4v',
#   'duration_ms': 263400,
#   'time_signature': 3},
#  {'track_id': '5HCyWlXZPP0y6Gqq8TgA20',
#   'track_name': 'STAY (with Justin Bieber)',
#   'track_pop': 87,
#   'album': 'STAY (with Justin Bieber)',
#   'release_date': '2021-07-09',
#   'duration': 141805,
#   'explicit': True,
#   'artist_name': 'The Kid LAROI',
#   'artist_pop': 80,
#   'artist_genres': ['australian hip hop', 'pop'],
#   'danceability': 0.591,
#   'energy': 0.764,
#   'key': 1,
#   'loudness': -5.484,
#   'mode': 1,
#   'speechiness': 0.0483,
#   'acousticness': 0.0383,
#   'instrumentalness': 0,
#   'liveness': 0.103,
#   'valence': 0.478,
#   'tempo': 169.928,
#   'type': 'audio_features',
#   'id': '5HCyWlXZPP0y6Gqq8TgA20',
#   'uri': 'spotify:track:5HCyWlXZPP0y6Gqq8TgA20',
#   'track_href': 'https://api.spotify.com/v1/tracks/5HCyWlXZPP0y6Gqq8TgA20',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5HCyWlXZPP0y6Gqq8TgA20',
#   'duration_ms': 141806,
#   'time_signature': 4},
#  {'track_id': '2Fxmhks0bxGSBdJ92vM42m',
#   'track_name': 'bad guy',
#   'track_pop': 83,
#   'album': 'WHEN WE ALL FALL ASLEEP, WHERE DO WE GO?',
#   'release_date': '2019-03-29',
#   'duration': 194087,
#   'explicit': False,
#   'artist_name': 'Billie Eilish',
#   'artist_pop': 88,
#   'artist_genres': ['art pop', 'electropop', 'pop'],
#   'danceability': 0.701,
#   'energy': 0.425,
#   'key': 7,
#   'loudness': -10.965,
#   'mode': 1,
#   'speechiness': 0.375,
#   'acousticness': 0.328,
#   'instrumentalness': 0.13,
#   'liveness': 0.1,
#   'valence': 0.562,
#   'tempo': 135.128,
#   'type': 'audio_features',
#   'id': '2Fxmhks0bxGSBdJ92vM42m',
#   'uri': 'spotify:track:2Fxmhks0bxGSBdJ92vM42m',
#   'track_href': 'https://api.spotify.com/v1/tracks/2Fxmhks0bxGSBdJ92vM42m',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2Fxmhks0bxGSBdJ92vM42m',
#   'duration_ms': 194088,
#   'time_signature': 4},
#  {'track_id': '1Pw5C4N6Fn5E4mGCxmbbVa',
#   'track_name': "Say You Won't Let Go",
#   'track_pop': 67,
#   'album': "Say You Won't Let Go",
#   'release_date': '2016-09-09',
#   'duration': 211240,
#   'explicit': False,
#   'artist_name': 'James Arthur',
#   'artist_pop': 79,
#   'artist_genres': ['pop', 'talent show', 'uk pop'],
#   'danceability': 0.4,
#   'energy': 0.564,
#   'key': 10,
#   'loudness': -7.444,
#   'mode': 1,
#   'speechiness': 0.0523,
#   'acousticness': 0.693,
#   'instrumentalness': 0,
#   'liveness': 0.0863,
#   'valence': 0.483,
#   'tempo': 99.269,
#   'type': 'audio_features',
#   'id': '1Pw5C4N6Fn5E4mGCxmbbVa',
#   'uri': 'spotify:track:1Pw5C4N6Fn5E4mGCxmbbVa',
#   'track_href': 'https://api.spotify.com/v1/tracks/1Pw5C4N6Fn5E4mGCxmbbVa',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1Pw5C4N6Fn5E4mGCxmbbVa',
#   'duration_ms': 211240,
#   'time_signature': 4},
#  {'track_id': '2NR99tTHkakE63qMMnkgZV',
#   'track_name': 'Thinking Out Loud',
#   'track_pop': 0,
#   'album': 'Thinking Out Loud',
#   'release_date': '2014-06-18',
#   'duration': 281560,
#   'explicit': False,
#   'artist_name': 'Ed Sheeran',
#   'artist_pop': 89,
#   'artist_genres': ['pop', 'uk pop'],
#   'danceability': 0.781,
#   'energy': 0.445,
#   'key': 2,
#   'loudness': -6.061,
#   'mode': 1,
#   'speechiness': 0.0295,
#   'acousticness': 0.474,
#   'instrumentalness': 0,
#   'liveness': 0.184,
#   'valence': 0.591,
#   'tempo': 78.998,
#   'type': 'audio_features',
#   'id': '2NR99tTHkakE63qMMnkgZV',
#   'uri': 'spotify:track:2NR99tTHkakE63qMMnkgZV',
#   'track_href': 'https://api.spotify.com/v1/tracks/2NR99tTHkakE63qMMnkgZV',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2NR99tTHkakE63qMMnkgZV',
#   'duration_ms': 281560,
#   'time_signature': 4},
#  {'track_id': '6CDzDgIUqeDY5g8ujExx2f',
#   'track_name': 'Heat Waves',
#   'track_pop': 83,
#   'album': 'Heat Waves',
#   'release_date': '2020-06-29',
#   'duration': 238805,
#   'explicit': False,
#   'artist_name': 'Glass Animals',
#   'artist_pop': 77,
#   'artist_genres': ['gauze pop', 'indietronica', 'shiver pop'],
#   'danceability': 0.761,
#   'energy': 0.525,
#   'key': 11,
#   'loudness': -6.9,
#   'mode': 1,
#   'speechiness': 0.0944,
#   'acousticness': 0.44,
#   'instrumentalness': 6.7e-06,
#   'liveness': 0.0921,
#   'valence': 0.531,
#   'tempo': 80.87,
#   'type': 'audio_features',
#   'id': '6CDzDgIUqeDY5g8ujExx2f',
#   'uri': 'spotify:track:6CDzDgIUqeDY5g8ujExx2f',
#   'track_href': 'https://api.spotify.com/v1/tracks/6CDzDgIUqeDY5g8ujExx2f',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6CDzDgIUqeDY5g8ujExx2f',
#   'duration_ms': 238805,
#   'time_signature': 4},
#  {'track_id': '1Bmn5aStO2S33dz1Di0g3K',
#   'track_name': 'Lucid Dreams',
#   'track_pop': 54,
#   'album': 'Lucid Dreams',
#   'release_date': '2018-05-04',
#   'duration': 239960,
#   'explicit': False,
#   'artist_name': 'Juice WRLD',
#   'artist_pop': 88,
#   'artist_genres': ['chicago rap', 'melodic rap'],
#   'danceability': 0.543,
#   'energy': 0.575,
#   'key': 6,
#   'loudness': -7.155,
#   'mode': 0,
#   'speechiness': 0.211,
#   'acousticness': 0.352,
#   'instrumentalness': 0,
#   'liveness': 0.28,
#   'valence': 0.234,
#   'tempo': 83.941,
#   'type': 'audio_features',
#   'id': '1Bmn5aStO2S33dz1Di0g3K',
#   'uri': 'spotify:track:1Bmn5aStO2S33dz1Di0g3K',
#   'track_href': 'https://api.spotify.com/v1/tracks/1Bmn5aStO2S33dz1Di0g3K',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1Bmn5aStO2S33dz1Di0g3K',
#   'duration_ms': 239960,
#   'time_signature': 4},
#  {'track_id': '6WrI0LAC5M1Rw2MnX2ZvEg',
#   'track_name': "Don't Start Now",
#   'track_pop': 78,
#   'album': "Don't Start Now",
#   'release_date': '2019-10-31',
#   'duration': 183290,
#   'explicit': False,
#   'artist_name': 'Dua Lipa',
#   'artist_pop': 87,
#   'artist_genres': ['dance pop', 'pop', 'uk pop'],
#   'danceability': 0.794,
#   'energy': 0.793,
#   'key': 11,
#   'loudness': -4.521,
#   'mode': 0,
#   'speechiness': 0.0842,
#   'acousticness': 0.0125,
#   'instrumentalness': 0,
#   'liveness': 0.0952,
#   'valence': 0.677,
#   'tempo': 123.941,
#   'type': 'audio_features',
#   'id': '6WrI0LAC5M1Rw2MnX2ZvEg',
#   'uri': 'spotify:track:6WrI0LAC5M1Rw2MnX2ZvEg',
#   'track_href': 'https://api.spotify.com/v1/tracks/6WrI0LAC5M1Rw2MnX2ZvEg',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6WrI0LAC5M1Rw2MnX2ZvEg',
#   'duration_ms': 183290,
#   'time_signature': 4},
#  {'track_id': '6DCZcSspjsKoFjzjrWoCdn',
#   'track_name': "God's Plan",
#   'track_pop': 83,
#   'album': 'Scorpion',
#   'release_date': '2018-06-29',
#   'duration': 198973,
#   'explicit': True,
#   'artist_name': 'Drake',
#   'artist_pop': 97,
#   'artist_genres': ['canadian hip hop',
#    'canadian pop',
#    'hip hop',
#    'rap',
#    'toronto rap'],
#   'danceability': 0.754,
#   'energy': 0.449,
#   'key': 7,
#   'loudness': -9.211,
#   'mode': 1,
#   'speechiness': 0.109,
#   'acousticness': 0.0332,
#   'instrumentalness': 8.29e-05,
#   'liveness': 0.552,
#   'valence': 0.357,
#   'tempo': 77.169,
#   'type': 'audio_features',
#   'id': '6DCZcSspjsKoFjzjrWoCdn',
#   'uri': 'spotify:track:6DCZcSspjsKoFjzjrWoCdn',
#   'track_href': 'https://api.spotify.com/v1/tracks/6DCZcSspjsKoFjzjrWoCdn',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6DCZcSspjsKoFjzjrWoCdn',
#   'duration_ms': 198973,
#   'time_signature': 4},
#  {'track_id': '7lQqaqZu0vjxzpdATOIsDt',
#   'track_name': 'Starboy',
#   'track_pop': 0,
#   'album': 'Starboy',
#   'release_date': '2016-09-22',
#   'duration': 230466,
#   'explicit': True,
#   'artist_name': 'The Weeknd',
#   'artist_pop': 93,
#   'artist_genres': ['canadian contemporary r&b', 'canadian pop', 'pop'],
#   'danceability': 0.68,
#   'energy': 0.594,
#   'key': 7,
#   'loudness': -7.021,
#   'mode': 1,
#   'speechiness': 0.28,
#   'acousticness': 0.159,
#   'instrumentalness': 2.35e-06,
#   'liveness': 0.134,
#   'valence': 0.475,
#   'tempo': 186.04,
#   'type': 'audio_features',
#   'id': '7lQqaqZu0vjxzpdATOIsDt',
#   'uri': 'spotify:track:7lQqaqZu0vjxzpdATOIsDt',
#   'track_href': 'https://api.spotify.com/v1/tracks/7lQqaqZu0vjxzpdATOIsDt',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7lQqaqZu0vjxzpdATOIsDt',
#   'duration_ms': 230467,
#   'time_signature': 4},
#  {'track_id': '5tIJb0C5rIbiDijHl41byE',
#   'track_name': 'Photograph',
#   'track_pop': 0,
#   'album': 'Photograph',
#   'release_date': '2014-06-20',
#   'duration': 258986,
#   'explicit': False,
#   'artist_name': 'Ed Sheeran',
#   'artist_pop': 89,
#   'artist_genres': ['pop', 'uk pop'],
#   'danceability': 0.614,
#   'energy': 0.379,
#   'key': 4,
#   'loudness': -10.48,
#   'mode': 1,
#   'speechiness': 0.0476,
#   'acousticness': 0.607,
#   'instrumentalness': 0.000464,
#   'liveness': 0.0986,
#   'valence': 0.201,
#   'tempo': 107.989,
#   'type': 'audio_features',
#   'id': '5tIJb0C5rIbiDijHl41byE',
#   'uri': 'spotify:track:5tIJb0C5rIbiDijHl41byE',
#   'track_href': 'https://api.spotify.com/v1/tracks/5tIJb0C5rIbiDijHl41byE',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5tIJb0C5rIbiDijHl41byE',
#   'duration_ms': 258987,
#   'time_signature': 4},
#  {'track_id': '1e9oZCCiX42nJl0AcqriVo',
#   'track_name': 'Watermelon Sugar',
#   'track_pop': 7,
#   'album': 'Watermelon Sugar',
#   'release_date': '2019-11-17',
#   'duration': 174000,
#   'explicit': False,
#   'artist_name': 'Harry Styles',
#   'artist_pop': 89,
#   'artist_genres': ['pop'],
#   'danceability': 0.548,
#   'energy': 0.816,
#   'key': 0,
#   'loudness': -4.209,
#   'mode': 1,
#   'speechiness': 0.0465,
#   'acousticness': 0.122,
#   'instrumentalness': 0,
#   'liveness': 0.335,
#   'valence': 0.557,
#   'tempo': 95.39,
#   'type': 'audio_features',
#   'id': '1e9oZCCiX42nJl0AcqriVo',
#   'uri': 'spotify:track:1e9oZCCiX42nJl0AcqriVo',
#   'track_href': 'https://api.spotify.com/v1/tracks/1e9oZCCiX42nJl0AcqriVo',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1e9oZCCiX42nJl0AcqriVo',
#   'duration_ms': 174000,
#   'time_signature': 4},
#  {'track_id': '0u2P5u6lvoDfwTYjAADbn4',
#   'track_name': 'lovely (with Khalid)',
#   'track_pop': 88,
#   'album': 'lovely (with Khalid)',
#   'release_date': '2018-04-19',
#   'duration': 200185,
#   'explicit': False,
#   'artist_name': 'Billie Eilish',
#   'artist_pop': 88,
#   'artist_genres': ['art pop', 'electropop', 'pop'],
#   'danceability': 0.351,
#   'energy': 0.296,
#   'key': 4,
#   'loudness': -10.109,
#   'mode': 0,
#   'speechiness': 0.0333,
#   'acousticness': 0.934,
#   'instrumentalness': 0,
#   'liveness': 0.095,
#   'valence': 0.12,
#   'tempo': 115.284,
#   'type': 'audio_features',
#   'id': '0u2P5u6lvoDfwTYjAADbn4',
#   'uri': 'spotify:track:0u2P5u6lvoDfwTYjAADbn4',
#   'track_href': 'https://api.spotify.com/v1/tracks/0u2P5u6lvoDfwTYjAADbn4',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0u2P5u6lvoDfwTYjAADbn4',
#   'duration_ms': 200186,
#   'time_signature': 4},
#  {'track_id': '2zImmNYRMK61rOsLyqtihJ',
#   'track_name': 'Bohemian Rhapsody',
#   'track_pop': 0,
#   'album': 'Bohemian Rhapsody',
#   'release_date': '2005-12-19',
#   'duration': 354346,
#   'explicit': False,
#   'artist_name': 'Queen',
#   'artist_pop': 84,
#   'artist_genres': ['classic rock', 'glam rock', 'rock'],
#   'danceability': 0.391,
#   'energy': 0.391,
#   'key': 0,
#   'loudness': -10.449,
#   'mode': 0,
#   'speechiness': 0.0522,
#   'acousticness': 0.298,
#   'instrumentalness': 0,
#   'liveness': 0.247,
#   'valence': 0.239,
#   'tempo': 145.456,
#   'type': 'audio_features',
#   'id': '2zImmNYRMK61rOsLyqtihJ',
#   'uri': 'spotify:track:2zImmNYRMK61rOsLyqtihJ',
#   'track_href': 'https://api.spotify.com/v1/tracks/2zImmNYRMK61rOsLyqtihJ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2zImmNYRMK61rOsLyqtihJ',
#   'duration_ms': 354347,
#   'time_signature': 4},
#  {'track_id': '1dNIEtp7AY3oDAKCGg2XkH',
#   'track_name': 'Something Just Like This',
#   'track_pop': 74,
#   'album': 'Something Just Like This',
#   'release_date': '2017-02-22',
#   'duration': 247626,
#   'explicit': False,
#   'artist_name': 'The Chainsmokers',
#   'artist_pop': 79,
#   'artist_genres': ['dance pop',
#    'edm',
#    'electropop',
#    'pop',
#    'pop dance',
#    'tropical house'],
#   'danceability': 0.607,
#   'energy': 0.649,
#   'key': 11,
#   'loudness': -6.695,
#   'mode': 0,
#   'speechiness': 0.0362,
#   'acousticness': 0.0306,
#   'instrumentalness': 2.46e-05,
#   'liveness': 0.174,
#   'valence': 0.505,
#   'tempo': 102.996,
#   'type': 'audio_features',
#   'id': '1dNIEtp7AY3oDAKCGg2XkH',
#   'uri': 'spotify:track:1dNIEtp7AY3oDAKCGg2XkH',
#   'track_href': 'https://api.spotify.com/v1/tracks/1dNIEtp7AY3oDAKCGg2XkH',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1dNIEtp7AY3oDAKCGg2XkH',
#   'duration_ms': 247627,
#   'time_signature': 4},
#  {'track_id': '5lK18Pt33xNudq4qYDxIm8',
#   'track_name': 'Shallow',
#   'track_pop': 1,
#   'album': 'Shallow',
#   'release_date': '2018-09-27',
#   'duration': 215733,
#   'explicit': False,
#   'artist_name': 'Lady Gaga',
#   'artist_pop': 84,
#   'artist_genres': ['art pop', 'dance pop', 'pop'],
#   'danceability': 0.572,
#   'energy': 0.385,
#   'key': 7,
#   'loudness': -6.362,
#   'mode': 1,
#   'speechiness': 0.0308,
#   'acousticness': 0.371,
#   'instrumentalness': 0,
#   'liveness': 0.231,
#   'valence': 0.323,
#   'tempo': 95.799,
#   'type': 'audio_features',
#   'id': '5lK18Pt33xNudq4qYDxIm8',
#   'uri': 'spotify:track:5lK18Pt33xNudq4qYDxIm8',
#   'track_href': 'https://api.spotify.com/v1/tracks/5lK18Pt33xNudq4qYDxIm8',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5lK18Pt33xNudq4qYDxIm8',
#   'duration_ms': 215733,
#   'time_signature': 4},
#  {'track_id': '35ieKju5aLWFN5UgfJ27mL',
#   'track_name': 'SAD!',
#   'track_pop': 0,
#   'album': 'SAD!',
#   'release_date': '2018-03-02',
#   'duration': 166568,
#   'explicit': True,
#   'artist_name': 'XXXTENTACION',
#   'artist_pop': 86,
#   'artist_genres': ['emo rap', 'miami hip hop'],
#   'danceability': 0.74,
#   'energy': 0.613,
#   'key': 8,
#   'loudness': -4.88,
#   'mode': 1,
#   'speechiness': 0.145,
#   'acousticness': 0.258,
#   'instrumentalness': 0.00372,
#   'liveness': 0.123,
#   'valence': 0.473,
#   'tempo': 75.023,
#   'type': 'audio_features',
#   'id': '35ieKju5aLWFN5UgfJ27mL',
#   'uri': 'spotify:track:35ieKju5aLWFN5UgfJ27mL',
#   'track_href': 'https://api.spotify.com/v1/tracks/35ieKju5aLWFN5UgfJ27mL',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/35ieKju5aLWFN5UgfJ27mL',
#   'duration_ms': 166568,
#   'time_signature': 4},
#  {'track_id': '5KFcz1OYNXyDX7HzSIsNdk',
#   'track_name': 'Love Yourself',
#   'track_pop': 0,
#   'album': 'Love Yourself',
#   'release_date': '2015-11-09',
#   'duration': 233746,
#   'explicit': False,
#   'artist_name': 'Justin Bieber',
#   'artist_pop': 89,
#   'artist_genres': ['canadian pop', 'pop'],
#   'danceability': 0.762,
#   'energy': 0.376,
#   'key': 4,
#   'loudness': -9.931,
#   'mode': 1,
#   'speechiness': 0.363,
#   'acousticness': 0.849,
#   'instrumentalness': 0,
#   'liveness': 0.205,
#   'valence': 0.541,
#   'tempo': 100.084,
#   'type': 'audio_features',
#   'id': '5KFcz1OYNXyDX7HzSIsNdk',
#   'uri': 'spotify:track:5KFcz1OYNXyDX7HzSIsNdk',
#   'track_href': 'https://api.spotify.com/v1/tracks/5KFcz1OYNXyDX7HzSIsNdk',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5KFcz1OYNXyDX7HzSIsNdk',
#   'duration_ms': 233747,
#   'time_signature': 4},
#  {'track_id': '4VginDwYTP2eaHJzO0QMjG',
#   'track_name': 'Circles',
#   'track_pop': 0,
#   'album': 'Circles',
#   'release_date': '2019-08-30',
#   'duration': 214906,
#   'explicit': False,
#   'artist_name': 'Post Malone',
#   'artist_pop': 87,
#   'artist_genres': ['dfw rap', 'melodic rap', 'rap'],
#   'danceability': 0.704,
#   'energy': 0.758,
#   'key': 0,
#   'loudness': -3.537,
#   'mode': 1,
#   'speechiness': 0.0402,
#   'acousticness': 0.233,
#   'instrumentalness': 0.00144,
#   'liveness': 0.0924,
#   'valence': 0.534,
#   'tempo': 120.003,
#   'type': 'audio_features',
#   'id': '4VginDwYTP2eaHJzO0QMjG',
#   'uri': 'spotify:track:4VginDwYTP2eaHJzO0QMjG',
#   'track_href': 'https://api.spotify.com/v1/tracks/4VginDwYTP2eaHJzO0QMjG',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4VginDwYTP2eaHJzO0QMjG',
#   'duration_ms': 214907,
#   'time_signature': 4},
#  {'track_id': '3bTZ9geYjyj9uBIT6gL5N6',
#   'track_name': 'All of Me',
#   'track_pop': 0,
#   'album': 'All of Me',
#   'release_date': '2013-08-08',
#   'duration': 269560,
#   'explicit': False,
#   'artist_name': 'John Legend',
#   'artist_pop': 77,
#   'artist_genres': ['neo soul',
#    'pop',
#    'pop soul',
#    'r&b',
#    'urban contemporary'],
#   'danceability': 0.422,
#   'energy': 0.264,
#   'key': 8,
#   'loudness': -7.064,
#   'mode': 1,
#   'speechiness': 0.0322,
#   'acousticness': 0.922,
#   'instrumentalness': 0,
#   'liveness': 0.132,
#   'valence': 0.331,
#   'tempo': 119.93,
#   'type': 'audio_features',
#   'id': '3bTZ9geYjyj9uBIT6gL5N6',
#   'uri': 'spotify:track:3bTZ9geYjyj9uBIT6gL5N6',
#   'track_href': 'https://api.spotify.com/v1/tracks/3bTZ9geYjyj9uBIT6gL5N6',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3bTZ9geYjyj9uBIT6gL5N6',
#   'duration_ms': 269560,
#   'time_signature': 4},
#  {'track_id': '2CLtQ937VJcxhMpiGLB7Jy',
#   'track_name': 'Take Me To Church',
#   'track_pop': 0,
#   'album': 'Take Me To Church',
#   'release_date': '2013-09-16',
#   'duration': 241573,
#   'explicit': False,
#   'artist_name': 'Hozier',
#   'artist_pop': 77,
#   'artist_genres': ['irish singer-songwriter', 'pop'],
#   'danceability': 0.568,
#   'energy': 0.666,
#   'key': 4,
#   'loudness': -5.28,
#   'mode': 0,
#   'speechiness': 0.0497,
#   'acousticness': 0.615,
#   'instrumentalness': 0,
#   'liveness': 0.121,
#   'valence': 0.411,
#   'tempo': 129.168,
#   'type': 'audio_features',
#   'id': '2CLtQ937VJcxhMpiGLB7Jy',
#   'uri': 'spotify:track:2CLtQ937VJcxhMpiGLB7Jy',
#   'track_href': 'https://api.spotify.com/v1/tracks/2CLtQ937VJcxhMpiGLB7Jy',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2CLtQ937VJcxhMpiGLB7Jy',
#   'duration_ms': 241573,
#   'time_signature': 4},
#  {'track_id': '0oP9pK1D1lNF3Lb7jkl6Xx',
#   'track_name': 'Thunder',
#   'track_pop': 0,
#   'album': 'Thunder',
#   'release_date': '2017-04-27',
#   'duration': 187761,
#   'explicit': False,
#   'artist_name': 'Imagine Dragons',
#   'artist_pop': 87,
#   'artist_genres': ['modern rock', 'rock'],
#   'danceability': 0.608,
#   'energy': 0.841,
#   'key': 0,
#   'loudness': -3.798,
#   'mode': 1,
#   'speechiness': 0.0464,
#   'acousticness': 0.00593,
#   'instrumentalness': 0.0573,
#   'liveness': 0.121,
#   'valence': 0.274,
#   'tempo': 167.969,
#   'type': 'audio_features',
#   'id': '0oP9pK1D1lNF3Lb7jkl6Xx',
#   'uri': 'spotify:track:0oP9pK1D1lNF3Lb7jkl6Xx',
#   'track_href': 'https://api.spotify.com/v1/tracks/0oP9pK1D1lNF3Lb7jkl6Xx',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0oP9pK1D1lNF3Lb7jkl6Xx',
#   'duration_ms': 187761,
#   'time_signature': 4},
#  {'track_id': '14msK75pk3pA33pzPVNtBF',
#   'track_name': '7 rings',
#   'track_pop': 0,
#   'album': '7 rings',
#   'release_date': '2019-01-18',
#   'duration': 178640,
#   'explicit': True,
#   'artist_name': 'Ariana Grande',
#   'artist_pop': 88,
#   'artist_genres': ['dance pop', 'pop'],
#   'danceability': 0.725,
#   'energy': 0.321,
#   'key': 1,
#   'loudness': -10.744,
#   'mode': 0,
#   'speechiness': 0.323,
#   'acousticness': 0.578,
#   'instrumentalness': 0,
#   'liveness': 0.0884,
#   'valence': 0.319,
#   'tempo': 70.142,
#   'type': 'audio_features',
#   'id': '14msK75pk3pA33pzPVNtBF',
#   'uri': 'spotify:track:14msK75pk3pA33pzPVNtBF',
#   'track_href': 'https://api.spotify.com/v1/tracks/14msK75pk3pA33pzPVNtBF',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/14msK75pk3pA33pzPVNtBF',
#   'duration_ms': 178640,
#   'time_signature': 4},
#  {'track_id': '6gBFPUFcJLzWGx4lenP6h2',
#   'track_name': 'goosebumps',
#   'track_pop': 83,
#   'album': 'Birds In The Trap Sing McKnight',
#   'release_date': '2016-09-16',
#   'duration': 243836,
#   'explicit': True,
#   'artist_name': 'Travis Scott',
#   'artist_pop': 88,
#   'artist_genres': ['rap', 'slap house'],
#   'danceability': 0.841,
#   'energy': 0.728,
#   'key': 7,
#   'loudness': -3.37,
#   'mode': 1,
#   'speechiness': 0.0484,
#   'acousticness': 0.0847,
#   'instrumentalness': 0,
#   'liveness': 0.149,
#   'valence': 0.43,
#   'tempo': 130.049,
#   'type': 'audio_features',
#   'id': '6gBFPUFcJLzWGx4lenP6h2',
#   'uri': 'spotify:track:6gBFPUFcJLzWGx4lenP6h2',
#   'track_href': 'https://api.spotify.com/v1/tracks/6gBFPUFcJLzWGx4lenP6h2',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6gBFPUFcJLzWGx4lenP6h2',
#   'duration_ms': 243837,
#   'time_signature': 4},
#  {'track_id': '7m9OqQk4RVRkw9JJdeAw96',
#   'track_name': 'Jocelyn Flores',
#   'track_pop': 84,
#   'album': '17',
#   'release_date': '2017-08-25',
#   'duration': 119133,
#   'explicit': True,
#   'artist_name': 'XXXTENTACION',
#   'artist_pop': 86,
#   'artist_genres': ['emo rap', 'miami hip hop'],
#   'danceability': 0.872,
#   'energy': 0.391,
#   'key': 0,
#   'loudness': -9.144,
#   'mode': 0,
#   'speechiness': 0.242,
#   'acousticness': 0.469,
#   'instrumentalness': 4.13e-06,
#   'liveness': 0.297,
#   'valence': 0.437,
#   'tempo': 134.021,
#   'type': 'audio_features',
#   'id': '7m9OqQk4RVRkw9JJdeAw96',
#   'uri': 'spotify:track:7m9OqQk4RVRkw9JJdeAw96',
#   'track_href': 'https://api.spotify.com/v1/tracks/7m9OqQk4RVRkw9JJdeAw96',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7m9OqQk4RVRkw9JJdeAw96',
#   'duration_ms': 119133,
#   'time_signature': 4},
#  {'track_id': '0ofbQMrRDsUaVKq2mGLEAb',
#   'track_name': 'Havana (feat. Young Thug)',
#   'track_pop': 0,
#   'album': 'Havana (feat. Young Thug)',
#   'release_date': '2017-08-03',
#   'duration': 216896,
#   'explicit': False,
#   'artist_name': 'Camila Cabello',
#   'artist_pop': 80,
#   'artist_genres': ['dance pop', 'pop', 'post-teen pop'],
#   'danceability': 0.768,
#   'energy': 0.517,
#   'key': 7,
#   'loudness': -4.323,
#   'mode': 0,
#   'speechiness': 0.0312,
#   'acousticness': 0.186,
#   'instrumentalness': 3.8e-05,
#   'liveness': 0.104,
#   'valence': 0.418,
#   'tempo': 104.992,
#   'type': 'audio_features',
#   'id': '0ofbQMrRDsUaVKq2mGLEAb',
#   'uri': 'spotify:track:0ofbQMrRDsUaVKq2mGLEAb',
#   'track_href': 'https://api.spotify.com/v1/tracks/0ofbQMrRDsUaVKq2mGLEAb',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0ofbQMrRDsUaVKq2mGLEAb',
#   'duration_ms': 216897,
#   'time_signature': 4},
#  {'track_id': '2QjOHCTQ1Jl3zawyYOpxh6',
#   'track_name': 'Sweater Weather',
#   'track_pop': 92,
#   'album': 'I Love You.',
#   'release_date': '2013-04-19',
#   'duration': 240400,
#   'explicit': False,
#   'artist_name': 'The Neighbourhood',
#   'artist_pop': 84,
#   'artist_genres': ['modern alternative rock',
#    'modern rock',
#    'pop',
#    'shimmer pop'],
#   'danceability': 0.612,
#   'energy': 0.807,
#   'key': 10,
#   'loudness': -2.81,
#   'mode': 1,
#   'speechiness': 0.0336,
#   'acousticness': 0.0495,
#   'instrumentalness': 0.0177,
#   'liveness': 0.101,
#   'valence': 0.398,
#   'tempo': 124.053,
#   'type': 'audio_features',
#   'id': '2QjOHCTQ1Jl3zawyYOpxh6',
#   'uri': 'spotify:track:2QjOHCTQ1Jl3zawyYOpxh6',
#   'track_href': 'https://api.spotify.com/v1/tracks/2QjOHCTQ1Jl3zawyYOpxh6',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2QjOHCTQ1Jl3zawyYOpxh6',
#   'duration_ms': 240400,
#   'time_signature': 4},
#  {'track_id': '2eMwDehkIC1j68U6FA3Eiq',
#   'track_name': 'XO TOUR Llif3',
#   'track_pop': 0,
#   'album': 'XO TOUR Llif3',
#   'release_date': '2017-03-24',
#   'duration': 182706,
#   'explicit': True,
#   'artist_name': 'Lil Uzi Vert',
#   'artist_pop': 85,
#   'artist_genres': ['melodic rap', 'philly rap', 'rap', 'trap'],
#   'danceability': 0.732,
#   'energy': 0.75,
#   'key': 11,
#   'loudness': -6.366,
#   'mode': 0,
#   'speechiness': 0.231,
#   'acousticness': 0.00264,
#   'instrumentalness': 0,
#   'liveness': 0.109,
#   'valence': 0.401,
#   'tempo': 155.096,
#   'type': 'audio_features',
#   'id': '2eMwDehkIC1j68U6FA3Eiq',
#   'uri': 'spotify:track:2eMwDehkIC1j68U6FA3Eiq',
#   'track_href': 'https://api.spotify.com/v1/tracks/2eMwDehkIC1j68U6FA3Eiq',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2eMwDehkIC1j68U6FA3Eiq',
#   'duration_ms': 182707,
#   'time_signature': 4},
#  {'track_id': '0lAB2lC6h4YhBIdkYYbpQH',
#   'track_name': 'Stressed Out',
#   'track_pop': 47,
#   'album': 'Stressed Out',
#   'release_date': '2015-04-28',
#   'duration': 202333,
#   'explicit': False,
#   'artist_name': 'Twenty One Pilots',
#   'artist_pop': 79,
#   'artist_genres': ['modern rock', 'rock'],
#   'danceability': 0.734,
#   'energy': 0.637,
#   'key': 4,
#   'loudness': -5.677,
#   'mode': 0,
#   'speechiness': 0.141,
#   'acousticness': 0.0462,
#   'instrumentalness': 2.29e-05,
#   'liveness': 0.0602,
#   'valence': 0.648,
#   'tempo': 169.977,
#   'type': 'audio_features',
#   'id': '0lAB2lC6h4YhBIdkYYbpQH',
#   'uri': 'spotify:track:0lAB2lC6h4YhBIdkYYbpQH',
#   'track_href': 'https://api.spotify.com/v1/tracks/0lAB2lC6h4YhBIdkYYbpQH',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0lAB2lC6h4YhBIdkYYbpQH',
#   'duration_ms': 202333,
#   'time_signature': 4},
#  {'track_id': '2ekn2ttSfGqwhhate0LSR0',
#   'track_name': 'New Rules',
#   'track_pop': 80,
#   'album': 'Dua Lipa (Deluxe)',
#   'release_date': '2017-06-02',
#   'duration': 209320,
#   'explicit': False,
#   'artist_name': 'Dua Lipa',
#   'artist_pop': 87,
#   'artist_genres': ['dance pop', 'pop', 'uk pop'],
#   'danceability': 0.762,
#   'energy': 0.7,
#   'key': 9,
#   'loudness': -6.021,
#   'mode': 0,
#   'speechiness': 0.0694,
#   'acousticness': 0.00261,
#   'instrumentalness': 1.56e-05,
#   'liveness': 0.153,
#   'valence': 0.608,
#   'tempo': 116.073,
#   'type': 'audio_features',
#   'id': '2ekn2ttSfGqwhhate0LSR0',
#   'uri': 'spotify:track:2ekn2ttSfGqwhhate0LSR0',
#   'track_href': 'https://api.spotify.com/v1/tracks/2ekn2ttSfGqwhhate0LSR0',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2ekn2ttSfGqwhhate0LSR0',
#   'duration_ms': 209320,
#   'time_signature': 4},
#  {'track_id': '2dpaYNEQHiRxtZbfNsse99',
#   'track_name': 'Happier',
#   'track_pop': 82,
#   'album': 'Happier',
#   'release_date': '2018-08-17',
#   'duration': 214289,
#   'explicit': False,
#   'artist_name': 'Marshmello',
#   'artist_pop': 82,
#   'artist_genres': ['brostep',
#    'dance pop',
#    'edm',
#    'pop',
#    'pop dance',
#    'progressive electro house'],
#   'danceability': 0.687,
#   'energy': 0.792,
#   'key': 5,
#   'loudness': -2.749,
#   'mode': 1,
#   'speechiness': 0.0452,
#   'acousticness': 0.191,
#   'instrumentalness': 0,
#   'liveness': 0.167,
#   'valence': 0.671,
#   'tempo': 100.015,
#   'type': 'audio_features',
#   'id': '2dpaYNEQHiRxtZbfNsse99',
#   'uri': 'spotify:track:2dpaYNEQHiRxtZbfNsse99',
#   'track_href': 'https://api.spotify.com/v1/tracks/2dpaYNEQHiRxtZbfNsse99',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2dpaYNEQHiRxtZbfNsse99',
#   'duration_ms': 214290,
#   'time_signature': 4},
#  {'track_id': '2xLMifQCjDGFmkHkpNLD9h',
#   'track_name': 'SICKO MODE',
#   'track_pop': 82,
#   'album': 'ASTROWORLD',
#   'release_date': '2018-08-03',
#   'duration': 312820,
#   'explicit': True,
#   'artist_name': 'Travis Scott',
#   'artist_pop': 88,
#   'artist_genres': ['rap', 'slap house'],
#   'danceability': 0.834,
#   'energy': 0.73,
#   'key': 8,
#   'loudness': -3.714,
#   'mode': 1,
#   'speechiness': 0.222,
#   'acousticness': 0.00513,
#   'instrumentalness': 0,
#   'liveness': 0.124,
#   'valence': 0.446,
#   'tempo': 155.008,
#   'type': 'audio_features',
#   'id': '2xLMifQCjDGFmkHkpNLD9h',
#   'uri': 'spotify:track:2xLMifQCjDGFmkHkpNLD9h',
#   'track_href': 'https://api.spotify.com/v1/tracks/2xLMifQCjDGFmkHkpNLD9h',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2xLMifQCjDGFmkHkpNLD9h',
#   'duration_ms': 312820,
#   'time_signature': 4},
#  {'track_id': '31c9IHwCIONmUYW0jL7Riz',
#   'track_name': 'HUMBLE.',
#   'track_pop': 0,
#   'album': 'HUMBLE.',
#   'release_date': '2017-03-31',
#   'duration': 177604,
#   'explicit': True,
#   'artist_name': 'Kendrick Lamar',
#   'artist_pop': 88,
#   'artist_genres': ['conscious hip hop', 'hip hop', 'rap', 'west coast rap'],
#   'danceability': 0.907,
#   'energy': 0.591,
#   'key': 1,
#   'loudness': -7.507,
#   'mode': 0,
#   'speechiness': 0.105,
#   'acousticness': 0.000359,
#   'instrumentalness': 2.81e-05,
#   'liveness': 0.0897,
#   'valence': 0.418,
#   'tempo': 149.992,
#   'type': 'audio_features',
#   'id': '31c9IHwCIONmUYW0jL7Riz',
#   'uri': 'spotify:track:31c9IHwCIONmUYW0jL7Riz',
#   'track_href': 'https://api.spotify.com/v1/tracks/31c9IHwCIONmUYW0jL7Riz',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/31c9IHwCIONmUYW0jL7Riz',
#   'duration_ms': 177604,
#   'time_signature': 4},
#  {'track_id': '2ueOPTvqwFPYLXswCmRTTw',
#   'track_name': 'Let Her Go',
#   'track_pop': 29,
#   'album': 'Let Her Go',
#   'release_date': '2012-11-12',
#   'duration': 252866,
#   'explicit': False,
#   'artist_name': 'Passenger',
#   'artist_pop': 70,
#   'artist_genres': ['folk-pop', 'neo mellow'],
#   'danceability': 0.509,
#   'energy': 0.538,
#   'key': 7,
#   'loudness': -7.335,
#   'mode': 1,
#   'speechiness': 0.0572,
#   'acousticness': 0.385,
#   'instrumentalness': 0,
#   'liveness': 0.104,
#   'valence': 0.244,
#   'tempo': 75.089,
#   'type': 'audio_features',
#   'id': '2ueOPTvqwFPYLXswCmRTTw',
#   'uri': 'spotify:track:2ueOPTvqwFPYLXswCmRTTw',
#   'track_href': 'https://api.spotify.com/v1/tracks/2ueOPTvqwFPYLXswCmRTTw',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2ueOPTvqwFPYLXswCmRTTw',
#   'duration_ms': 252867,
#   'time_signature': 4},
#  {'track_id': '2tpWsVSb9UEmDRxAl1zhX1',
#   'track_name': 'Counting Stars',
#   'track_pop': 83,
#   'album': 'Native',
#   'release_date': '2013-01-01',
#   'duration': 257266,
#   'explicit': False,
#   'artist_name': 'OneRepublic',
#   'artist_pop': 84,
#   'artist_genres': ['piano rock', 'pop'],
#   'danceability': 0.664,
#   'energy': 0.705,
#   'key': 1,
#   'loudness': -4.972,
#   'mode': 0,
#   'speechiness': 0.0382,
#   'acousticness': 0.0654,
#   'instrumentalness': 0,
#   'liveness': 0.118,
#   'valence': 0.477,
#   'tempo': 122.016,
#   'type': 'audio_features',
#   'id': '2tpWsVSb9UEmDRxAl1zhX1',
#   'uri': 'spotify:track:2tpWsVSb9UEmDRxAl1zhX1',
#   'track_href': 'https://api.spotify.com/v1/tracks/2tpWsVSb9UEmDRxAl1zhX1',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2tpWsVSb9UEmDRxAl1zhX1',
#   'duration_ms': 257267,
#   'time_signature': 4},
#  {'track_id': '4QRZirU4s1f30iDHzuKncj',
#   'track_name': 'Wake Me Up',
#   'track_pop': 50,
#   'album': 'Wake Me Up',
#   'release_date': '2013-07-30',
#   'duration': 249693,
#   'explicit': False,
#   'artist_name': 'Avicii',
#   'artist_pop': 80,
#   'artist_genres': ['dance pop', 'edm', 'pop', 'pop dance', 'pop rap'],
#   'danceability': 0.516,
#   'energy': 0.806,
#   'key': 2,
#   'loudness': -5.133,
#   'mode': 1,
#   'speechiness': 0.0538,
#   'acousticness': 0.00389,
#   'instrumentalness': 0.000674,
#   'liveness': 0.115,
#   'valence': 0.577,
#   'tempo': 124.118,
#   'type': 'audio_features',
#   'id': '4QRZirU4s1f30iDHzuKncj',
#   'uri': 'spotify:track:4QRZirU4s1f30iDHzuKncj',
#   'track_href': 'https://api.spotify.com/v1/tracks/4QRZirU4s1f30iDHzuKncj',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4QRZirU4s1f30iDHzuKncj',
#   'duration_ms': 249693,
#   'time_signature': 4},
#  {'track_id': '2GpHJb7xGNBaIDTrBxjIu6',
#   'track_name': 'Sorry',
#   'track_pop': 0,
#   'album': 'Sorry',
#   'release_date': '2015-10-23',
#   'duration': 200786,
#   'explicit': False,
#   'artist_name': 'Justin Bieber',
#   'artist_pop': 89,
#   'artist_genres': ['canadian pop', 'pop'],
#   'danceability': 0.665,
#   'energy': 0.759,
#   'key': 0,
#   'loudness': -3.694,
#   'mode': 0,
#   'speechiness': 0.0399,
#   'acousticness': 0.0767,
#   'instrumentalness': 0,
#   'liveness': 0.313,
#   'valence': 0.389,
#   'tempo': 99.992,
#   'type': 'audio_features',
#   'id': '2GpHJb7xGNBaIDTrBxjIu6',
#   'uri': 'spotify:track:2GpHJb7xGNBaIDTrBxjIu6',
#   'track_href': 'https://api.spotify.com/v1/tracks/2GpHJb7xGNBaIDTrBxjIu6',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2GpHJb7xGNBaIDTrBxjIu6',
#   'duration_ms': 200787,
#   'time_signature': 4},
#  {'track_id': '1KqlVt63Q4bl1VdSlymr5C',
#   'track_name': 'Riptide',
#   'track_pop': 51,
#   'album': 'Riptide',
#   'release_date': '2013-05-21',
#   'duration': 204280,
#   'explicit': False,
#   'artist_name': 'Vance Joy',
#   'artist_pop': 74,
#   'artist_genres': ['folk-pop', 'pop'],
#   'danceability': 0.484,
#   'energy': 0.731,
#   'key': 1,
#   'loudness': -6.694,
#   'mode': 1,
#   'speechiness': 0.0379,
#   'acousticness': 0.431,
#   'instrumentalness': 0,
#   'liveness': 0.151,
#   'valence': 0.51,
#   'tempo': 101.654,
#   'type': 'audio_features',
#   'id': '1KqlVt63Q4bl1VdSlymr5C',
#   'uri': 'spotify:track:1KqlVt63Q4bl1VdSlymr5C',
#   'track_href': 'https://api.spotify.com/v1/tracks/1KqlVt63Q4bl1VdSlymr5C',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1KqlVt63Q4bl1VdSlymr5C',
#   'duration_ms': 204280,
#   'time_signature': 4},
#  {'track_id': '4KcVVhAaHxqtX2ANt4b3tc',
#   'track_name': 'Lean On',
#   'track_pop': 0,
#   'album': 'Lean On',
#   'release_date': '2015-03-02',
#   'duration': 176561,
#   'explicit': False,
#   'artist_name': 'Major Lazer',
#   'artist_pop': 73,
#   'artist_genres': ['dance pop',
#    'edm',
#    'electro house',
#    'moombahton',
#    'pop',
#    'pop dance',
#    'pop rap',
#    'tropical house'],
#   'danceability': 0.713,
#   'energy': 0.79,
#   'key': 7,
#   'loudness': -4.602,
#   'mode': 0,
#   'speechiness': 0.0574,
#   'acousticness': 0.00339,
#   'instrumentalness': 0.000868,
#   'liveness': 0.485,
#   'valence': 0.308,
#   'tempo': 98.011,
#   'type': 'audio_features',
#   'id': '4KcVVhAaHxqtX2ANt4b3tc',
#   'uri': 'spotify:track:4KcVVhAaHxqtX2ANt4b3tc',
#   'track_href': 'https://api.spotify.com/v1/tracks/4KcVVhAaHxqtX2ANt4b3tc',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4KcVVhAaHxqtX2ANt4b3tc',
#   'duration_ms': 176561,
#   'time_signature': 4},
#  {'track_id': '0lYBSQXN6rCTvUZvg9S0lU',
#   'track_name': 'Let Me Love You',
#   'track_pop': 83,
#   'album': 'Encore',
#   'release_date': '2016-08-05',
#   'duration': 205946,
#   'explicit': False,
#   'artist_name': 'DJ Snake',
#   'artist_pop': 76,
#   'artist_genres': ['dance pop',
#    'edm',
#    'electronic trap',
#    'pop',
#    'pop dance',
#    'pop rap'],
#   'danceability': 0.649,
#   'energy': 0.716,
#   'key': 8,
#   'loudness': -5.371,
#   'mode': 1,
#   'speechiness': 0.0349,
#   'acousticness': 0.0863,
#   'instrumentalness': 2.63e-05,
#   'liveness': 0.135,
#   'valence': 0.163,
#   'tempo': 99.988,
#   'type': 'audio_features',
#   'id': '0lYBSQXN6rCTvUZvg9S0lU',
#   'uri': 'spotify:track:0lYBSQXN6rCTvUZvg9S0lU',
#   'track_href': 'https://api.spotify.com/v1/tracks/0lYBSQXN6rCTvUZvg9S0lU',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0lYBSQXN6rCTvUZvg9S0lU',
#   'duration_ms': 205947,
#   'time_signature': 4},
#  {'track_id': '56qwmfX8r5SznGSaayVIzK',
#   'track_name': 'Roses - Imanbek Remix',
#   'track_pop': 42,
#   'album': 'Roses (Imanbek Remix)',
#   'release_date': '2019-09-23',
#   'duration': 176218,
#   'explicit': False,
#   'artist_name': 'SAINt JHN',
#   'artist_pop': 69,
#   'artist_genres': ['melodic rap', 'rap', 'slap house', 'trap'],
#   'danceability': 0.784,
#   'energy': 0.721,
#   'key': 8,
#   'loudness': -5.457,
#   'mode': 1,
#   'speechiness': 0.0506,
#   'acousticness': 0.0149,
#   'instrumentalness': 0.00424,
#   'liveness': 0.285,
#   'valence': 0.895,
#   'tempo': 121.966,
#   'type': 'audio_features',
#   'id': '56qwmfX8r5SznGSaayVIzK',
#   'uri': 'spotify:track:56qwmfX8r5SznGSaayVIzK',
#   'track_href': 'https://api.spotify.com/v1/tracks/56qwmfX8r5SznGSaayVIzK',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/56qwmfX8r5SznGSaayVIzK',
#   'duration_ms': 176219,
#   'time_signature': 4},
#  {'track_id': '0ysmhSqZrkiRkRH4mH8rDn',
#   'track_name': 'The Hills',
#   'track_pop': 0,
#   'album': 'The Hills',
#   'release_date': '2015-05-27',
#   'duration': 242519,
#   'explicit': True,
#   'artist_name': 'The Weeknd',
#   'artist_pop': 93,
#   'artist_genres': ['canadian contemporary r&b', 'canadian pop', 'pop'],
#   'danceability': 0.576,
#   'energy': 0.55,
#   'key': 0,
#   'loudness': -7.01,
#   'mode': 0,
#   'speechiness': 0.0649,
#   'acousticness': 0.083,
#   'instrumentalness': 0,
#   'liveness': 0.139,
#   'valence': 0.107,
#   'tempo': 113.048,
#   'type': 'audio_features',
#   'id': '0ysmhSqZrkiRkRH4mH8rDn',
#   'uri': 'spotify:track:0ysmhSqZrkiRkRH4mH8rDn',
#   'track_href': 'https://api.spotify.com/v1/tracks/0ysmhSqZrkiRkRH4mH8rDn',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0ysmhSqZrkiRkRH4mH8rDn',
#   'duration_ms': 242519,
#   'time_signature': 4},
#  {'track_id': '7dt6x5M1jzdTEt8oCbisTK',
#   'track_name': 'Better Now',
#   'track_pop': 80,
#   'album': 'beerbongs & bentleys',
#   'release_date': '2018-04-27',
#   'duration': 231266,
#   'explicit': True,
#   'artist_name': 'Post Malone',
#   'artist_pop': 87,
#   'artist_genres': ['dfw rap', 'melodic rap', 'rap'],
#   'danceability': 0.68,
#   'energy': 0.578,
#   'key': 10,
#   'loudness': -5.804,
#   'mode': 1,
#   'speechiness': 0.04,
#   'acousticness': 0.331,
#   'instrumentalness': 0,
#   'liveness': 0.135,
#   'valence': 0.341,
#   'tempo': 145.038,
#   'type': 'audio_features',
#   'id': '7dt6x5M1jzdTEt8oCbisTK',
#   'uri': 'spotify:track:7dt6x5M1jzdTEt8oCbisTK',
#   'track_href': 'https://api.spotify.com/v1/tracks/7dt6x5M1jzdTEt8oCbisTK',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7dt6x5M1jzdTEt8oCbisTK',
#   'duration_ms': 231267,
#   'time_signature': 4},
#  {'track_id': '6PERP62TejQjgHu81OHxgM',
#   'track_name': 'good 4 u',
#   'track_pop': 25,
#   'album': 'good 4 u',
#   'release_date': '2021-05-14',
#   'duration': 178147,
#   'explicit': True,
#   'artist_name': 'Olivia Rodrigo',
#   'artist_pop': 83,
#   'artist_genres': ['pop'],
#   'danceability': 0.556,
#   'energy': 0.661,
#   'key': 6,
#   'loudness': -5.052,
#   'mode': 0,
#   'speechiness': 0.204,
#   'acousticness': 0.3,
#   'instrumentalness': 0,
#   'liveness': 0.101,
#   'valence': 0.668,
#   'tempo': 168.56,
#   'type': 'audio_features',
#   'id': '6PERP62TejQjgHu81OHxgM',
#   'uri': 'spotify:track:6PERP62TejQjgHu81OHxgM',
#   'track_href': 'https://api.spotify.com/v1/tracks/6PERP62TejQjgHu81OHxgM',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6PERP62TejQjgHu81OHxgM',
#   'duration_ms': 178148,
#   'time_signature': 4},
#  {'track_id': '6PwfLLwtXhCcp1PiBpjJkJ',
#   'track_name': "Can't Hold Us (feat. Ray Dalton)",
#   'track_pop': 0,
#   'album': "Can't Hold Us",
#   'release_date': '2011-08-16',
#   'duration': 264895,
#   'explicit': False,
#   'artist_name': 'Macklemore & Ryan Lewis',
#   'artist_pop': 73,
#   'artist_genres': ['dance pop', 'pop', 'pop rap', 'seattle hip hop'],
#   'danceability': 0.648,
#   'energy': 0.924,
#   'key': 2,
#   'loudness': -4.535,
#   'mode': 1,
#   'speechiness': 0.0754,
#   'acousticness': 0.03,
#   'instrumentalness': 0,
#   'liveness': 0.0988,
#   'valence': 0.829,
#   'tempo': 146.053,
#   'type': 'audio_features',
#   'id': '6PwfLLwtXhCcp1PiBpjJkJ',
#   'uri': 'spotify:track:6PwfLLwtXhCcp1PiBpjJkJ',
#   'track_href': 'https://api.spotify.com/v1/tracks/6PwfLLwtXhCcp1PiBpjJkJ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6PwfLLwtXhCcp1PiBpjJkJ',
#   'duration_ms': 264895,
#   'time_signature': 4},
#  {'track_id': '3a1lNhkSLSkpJE4MSHpDu9',
#   'track_name': 'Congratulations',
#   'track_pop': 81,
#   'album': 'Stoney (Deluxe)',
#   'release_date': '2016-12-09',
#   'duration': 220293,
#   'explicit': True,
#   'artist_name': 'Post Malone',
#   'artist_pop': 87,
#   'artist_genres': ['dfw rap', 'melodic rap', 'rap'],
#   'danceability': 0.63,
#   'energy': 0.804,
#   'key': 6,
#   'loudness': -4.183,
#   'mode': 1,
#   'speechiness': 0.0363,
#   'acousticness': 0.215,
#   'instrumentalness': 0,
#   'liveness': 0.253,
#   'valence': 0.492,
#   'tempo': 123.146,
#   'type': 'audio_features',
#   'id': '3a1lNhkSLSkpJE4MSHpDu9',
#   'uri': 'spotify:track:3a1lNhkSLSkpJE4MSHpDu9',
#   'track_href': 'https://api.spotify.com/v1/tracks/3a1lNhkSLSkpJE4MSHpDu9',
# ...
#   'instrumentalness': 0,
#   'liveness': 0.155,
#   'valence': 0.136,
#   'tempo': 92.928,
#   'type': 'audio_features',
#   'id': '6XHVuErjQ4XNm6nDPVCxVX',
#   'uri': 'spotify:track:6XHVuErjQ4XNm6nDPVCxVX',
#   'track_href': 'https://api.spotify.com/v1/tracks/6XHVuErjQ4XNm6nDPVCxVX',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6XHVuErjQ4XNm6nDPVCxVX',
#   'duration_ms': 260640,
#   'time_signature': 4},
#  {'track_id': '1wVuPmvt6AWvTL5W2GJnzZ',
#   'track_name': 'Talking to the Moon',
#   'track_pop': 76,
#   'album': 'Doo-Wops & Hooligans',
#   'release_date': '2010-10-05',
#   'duration': 217866,
#   'explicit': False,
#   'artist_name': 'Bruno Mars',
#   'artist_pop': 87,
#   'artist_genres': ['dance pop', 'pop'],
#   'danceability': 0.498,
#   'energy': 0.59,
#   'key': 1,
#   'loudness': -4.721,
#   'mode': 0,
#   'speechiness': 0.032,
#   'acousticness': 0.511,
#   'instrumentalness': 0,
#   'liveness': 0.107,
#   'valence': 0.0784,
#   'tempo': 145.867,
#   'type': 'audio_features',
#   'id': '1wVuPmvt6AWvTL5W2GJnzZ',
#   'uri': 'spotify:track:1wVuPmvt6AWvTL5W2GJnzZ',
#   'track_href': 'https://api.spotify.com/v1/tracks/1wVuPmvt6AWvTL5W2GJnzZ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1wVuPmvt6AWvTL5W2GJnzZ',
#   'duration_ms': 217867,
#   'time_signature': 4},
#  {'track_id': '0nLiqZ6A27jJri2VCalIUs',
#   'track_name': 'Nothing Else Matters',
#   'track_pop': 79,
#   'album': 'Metallica',
#   'release_date': '1991-08-12',
#   'duration': 388266,
#   'explicit': False,
#   'artist_name': 'Metallica',
#   'artist_pop': 81,
#   'artist_genres': ['hard rock',
#    'metal',
#    'old school thrash',
#    'rock',
#    'thrash metal'],
#   'danceability': 0.553,
#   'energy': 0.362,
#   'key': 4,
#   'loudness': -11.218,
#   'mode': 0,
#   'speechiness': 0.0263,
#   'acousticness': 0.0458,
#   'instrumentalness': 6.01e-06,
#   'liveness': 0.075,
#   'valence': 0.158,
#   'tempo': 142.352,
#   'type': 'audio_features',
#   'id': '0nLiqZ6A27jJri2VCalIUs',
#   'uri': 'spotify:track:0nLiqZ6A27jJri2VCalIUs',
#   'track_href': 'https://api.spotify.com/v1/tracks/0nLiqZ6A27jJri2VCalIUs',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0nLiqZ6A27jJri2VCalIUs',
#   'duration_ms': 388267,
#   'time_signature': 3},
#  {'track_id': '6I9VzXrHxO9rA9A5euc8Ak',
#   'track_name': 'Toxic',
#   'track_pop': 81,
#   'album': 'In The Zone',
#   'release_date': '2003-11-13',
#   'duration': 198800,
#   'explicit': False,
#   'artist_name': 'Britney Spears',
#   'artist_pop': 80,
#   'artist_genres': ['dance pop', 'pop'],
#   'danceability': 0.774,
#   'energy': 0.838,
#   'key': 5,
#   'loudness': -3.914,
#   'mode': 0,
#   'speechiness': 0.114,
#   'acousticness': 0.0249,
#   'instrumentalness': 0.025,
#   'liveness': 0.242,
#   'valence': 0.924,
#   'tempo': 143.04,
#   'type': 'audio_features',
#   'id': '6I9VzXrHxO9rA9A5euc8Ak',
#   'uri': 'spotify:track:6I9VzXrHxO9rA9A5euc8Ak',
#   'track_href': 'https://api.spotify.com/v1/tracks/6I9VzXrHxO9rA9A5euc8Ak',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6I9VzXrHxO9rA9A5euc8Ak',
#   'duration_ms': 198800,
#   'time_signature': 4},
#  {'track_id': '4kV4N9D1iKVxx1KLvtTpjS',
#   'track_name': "break up with your girlfriend, i'm bored",
#   'track_pop': 77,
#   'album': 'thank u, next',
#   'release_date': '2019-02-08',
#   'duration': 190440,
#   'explicit': True,
#   'artist_name': 'Ariana Grande',
#   'artist_pop': 88,
#   'artist_genres': ['dance pop', 'pop'],
#   'danceability': 0.726,
#   'energy': 0.554,
#   'key': 5,
#   'loudness': -5.29,
#   'mode': 0,
#   'speechiness': 0.0917,
#   'acousticness': 0.0421,
#   'instrumentalness': 0,
#   'liveness': 0.106,
#   'valence': 0.335,
#   'tempo': 169.999,
#   'type': 'audio_features',
#   'id': '4kV4N9D1iKVxx1KLvtTpjS',
#   'uri': 'spotify:track:4kV4N9D1iKVxx1KLvtTpjS',
#   'track_href': 'https://api.spotify.com/v1/tracks/4kV4N9D1iKVxx1KLvtTpjS',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4kV4N9D1iKVxx1KLvtTpjS',
#   'duration_ms': 190440,
#   'time_signature': 4},
#  {'track_id': '2aibwv5hGXSgw7Yru8IYTO',
#   'track_name': 'Snow (Hey Oh)',
#   'track_pop': 79,
#   'album': 'Stadium Arcadium',
#   'release_date': '2006-05-09',
#   'duration': 334666,
#   'explicit': False,
#   'artist_name': 'Red Hot Chili Peppers',
#   'artist_pop': 81,
#   'artist_genres': ['alternative rock',
#    'funk metal',
#    'funk rock',
#    'permanent wave'],
#   'danceability': 0.427,
#   'energy': 0.9,
#   'key': 11,
#   'loudness': -3.674,
#   'mode': 1,
#   'speechiness': 0.0499,
#   'acousticness': 0.116,
#   'instrumentalness': 1.75e-05,
#   'liveness': 0.119,
#   'valence': 0.599,
#   'tempo': 104.655,
#   'type': 'audio_features',
#   'id': '2aibwv5hGXSgw7Yru8IYTO',
#   'uri': 'spotify:track:2aibwv5hGXSgw7Yru8IYTO',
#   'track_href': 'https://api.spotify.com/v1/tracks/2aibwv5hGXSgw7Yru8IYTO',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2aibwv5hGXSgw7Yru8IYTO',
#   'duration_ms': 334667,
#   'time_signature': 4},
#  {'track_id': '7eBqSVxrzQZtK2mmgRG6lC',
#   'track_name': 'Murder On My Mind',
#   'track_pop': 78,
#   'album': 'I AM YOU',
#   'release_date': '2018-08-03',
#   'duration': 268434,
#   'explicit': True,
#   'artist_name': 'YNW Melly',
#   'artist_pop': 72,
#   'artist_genres': ['melodic rap', 'trap'],
#   'danceability': 0.759,
#   'energy': 0.73,
#   'key': 0,
#   'loudness': -7.985,
#   'mode': 0,
#   'speechiness': 0.0516,
#   'acousticness': 0.145,
#   'instrumentalness': 3.06e-06,
#   'liveness': 0.11,
#   'valence': 0.74,
#   'tempo': 115.007,
#   'type': 'audio_features',
#   'id': '7eBqSVxrzQZtK2mmgRG6lC',
#   'uri': 'spotify:track:7eBqSVxrzQZtK2mmgRG6lC',
#   'track_href': 'https://api.spotify.com/v1/tracks/7eBqSVxrzQZtK2mmgRG6lC',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7eBqSVxrzQZtK2mmgRG6lC',
#   'duration_ms': 268434,
#   'time_signature': 4},
#  {'track_id': '1ZMiCix7XSAbfAJlEZWMCp',
#   'track_name': 'Falling',
#   'track_pop': 83,
#   'album': 'Fine Line',
#   'release_date': '2019-12-13',
#   'duration': 240133,
#   'explicit': False,
#   'artist_name': 'Harry Styles',
#   'artist_pop': 89,
#   'artist_genres': ['pop'],
#   'danceability': 0.567,
#   'energy': 0.267,
#   'key': 4,
#   'loudness': -6.502,
#   'mode': 1,
#   'speechiness': 0.0299,
#   'acousticness': 0.839,
#   'instrumentalness': 1.46e-06,
#   'liveness': 0.089,
#   'valence': 0.0592,
#   'tempo': 110.011,
#   'type': 'audio_features',
#   'id': '1ZMiCix7XSAbfAJlEZWMCp',
#   'uri': 'spotify:track:1ZMiCix7XSAbfAJlEZWMCp',
#   'track_href': 'https://api.spotify.com/v1/tracks/1ZMiCix7XSAbfAJlEZWMCp',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1ZMiCix7XSAbfAJlEZWMCp',
#   'duration_ms': 240133,
#   'time_signature': 4},
#  {'track_id': '3nef5W8jTkXrOKgCu4kmq7',
#   'track_name': 'Dangerous Woman',
#   'track_pop': 73,
#   'album': 'Dangerous Woman',
#   'release_date': '2016-04-01',
#   'duration': 235946,
#   'explicit': False,
#   'artist_name': 'Ariana Grande',
#   'artist_pop': 88,
#   'artist_genres': ['dance pop', 'pop'],
#   'danceability': 0.662,
#   'energy': 0.602,
#   'key': 4,
#   'loudness': -5.369,
#   'mode': 0,
#   'speechiness': 0.0401,
#   'acousticness': 0.0529,
#   'instrumentalness': 0,
#   'liveness': 0.356,
#   'valence': 0.29,
#   'tempo': 133.969,
#   'type': 'audio_features',
#   'id': '3nef5W8jTkXrOKgCu4kmq7',
#   'uri': 'spotify:track:3nef5W8jTkXrOKgCu4kmq7',
#   'track_href': 'https://api.spotify.com/v1/tracks/3nef5W8jTkXrOKgCu4kmq7',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3nef5W8jTkXrOKgCu4kmq7',
#   'duration_ms': 235947,
#   'time_signature': 3},
#  {'track_id': '1vvNmPOiUuyCbgWmtc6yfm',
#   'track_name': 'My Way',
#   'track_pop': 76,
#   'album': 'My Way',
#   'release_date': '2016-09-16',
#   'duration': 219159,
#   'explicit': False,
#   'artist_name': 'Calvin Harris',
#   'artist_pop': 83,
#   'artist_genres': ['dance pop',
#    'edm',
#    'electro house',
#    'house',
#    'pop',
#    'progressive house',
#    'uk dance'],
#   'danceability': 0.818,
#   'energy': 0.913,
#   'key': 4,
#   'loudness': -3.06,
#   'mode': 0,
#   'speechiness': 0.0426,
#   'acousticness': 0.093,
#   'instrumentalness': 3.69e-05,
#   'liveness': 0.161,
#   'valence': 0.536,
#   'tempo': 119.986,
#   'type': 'audio_features',
#   'id': '1vvNmPOiUuyCbgWmtc6yfm',
#   'uri': 'spotify:track:1vvNmPOiUuyCbgWmtc6yfm',
#   'track_href': 'https://api.spotify.com/v1/tracks/1vvNmPOiUuyCbgWmtc6yfm',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1vvNmPOiUuyCbgWmtc6yfm',
#   'duration_ms': 219160,
#   'time_signature': 4},
#  {'track_id': '0ITfYkVUoFdPKd3BOAoYsH',
#   'track_name': 'Die For You',
#   'track_pop': 42,
#   'album': 'Die For You',
#   'release_date': '2016-11-26',
#   'duration': 260255,
#   'explicit': False,
#   'artist_name': 'The Weeknd',
#   'artist_pop': 93,
#   'artist_genres': ['canadian contemporary r&b', 'canadian pop', 'pop'],
#   'danceability': 0.602,
#   'energy': 0.505,
#   'key': 1,
#   'loudness': -8.197,
#   'mode': 0,
#   'speechiness': 0.0577,
#   'acousticness': 0.112,
#   'instrumentalness': 0,
#   'liveness': 0.155,
#   'valence': 0.457,
#   'tempo': 67.129,
#   'type': 'audio_features',
#   'id': '0ITfYkVUoFdPKd3BOAoYsH',
#   'uri': 'spotify:track:0ITfYkVUoFdPKd3BOAoYsH',
#   'track_href': 'https://api.spotify.com/v1/tracks/0ITfYkVUoFdPKd3BOAoYsH',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0ITfYkVUoFdPKd3BOAoYsH',
#   'duration_ms': 260256,
#   'time_signature': 4},
#  {'track_id': '1r9xUipOqoNwggBpENDsvJ',
#   'track_name': 'Enemy (with JID) - from the series Arcane League of Legends',
#   'track_pop': 85,
#   'album': 'Enemy (with JID) [from the series Arcane League of Legends]',
#   'release_date': '2021-10-28',
#   'duration': 173381,
#   'explicit': False,
#   'artist_name': 'Imagine Dragons',
#   'artist_pop': 87,
#   'artist_genres': ['modern rock', 'rock'],
#   'danceability': 0.728,
#   'energy': 0.783,
#   'key': 11,
#   'loudness': -4.424,
#   'mode': 0,
#   'speechiness': 0.266,
#   'acousticness': 0.237,
#   'instrumentalness': 0,
#   'liveness': 0.434,
#   'valence': 0.555,
#   'tempo': 77.011,
#   'type': 'audio_features',
#   'id': '1r9xUipOqoNwggBpENDsvJ',
#   'uri': 'spotify:track:1r9xUipOqoNwggBpENDsvJ',
#   'track_href': 'https://api.spotify.com/v1/tracks/1r9xUipOqoNwggBpENDsvJ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1r9xUipOqoNwggBpENDsvJ',
#   'duration_ms': 173381,
#   'time_signature': 4},
#  {'track_id': '6Sq7ltF9Qa7SNFBsV5Cogx',
#   'track_name': 'Me Porto Bonito',
#   'track_pop': 95,
#   'album': 'Un Verano Sin Ti',
#   'release_date': '2022-05-06',
#   'duration': 178567,
#   'explicit': True,
#   'artist_name': 'Bad Bunny',
#   'artist_pop': 97,
#   'artist_genres': ['reggaeton', 'trap latino'],
#   'danceability': 0.911,
#   'energy': 0.712,
#   'key': 1,
#   'loudness': -5.105,
#   'mode': 0,
#   'speechiness': 0.0817,
#   'acousticness': 0.0901,
#   'instrumentalness': 2.68e-05,
#   'liveness': 0.0933,
#   'valence': 0.425,
#   'tempo': 92.005,
#   'type': 'audio_features',
#   'id': '6Sq7ltF9Qa7SNFBsV5Cogx',
#   'uri': 'spotify:track:6Sq7ltF9Qa7SNFBsV5Cogx',
#   'track_href': 'https://api.spotify.com/v1/tracks/6Sq7ltF9Qa7SNFBsV5Cogx',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6Sq7ltF9Qa7SNFBsV5Cogx',
#   'duration_ms': 178567,
#   'time_signature': 4},
#  {'track_id': '0BxE4FqsDD1Ot4YuBXwAPp',
#   'track_name': '505',
#   'track_pop': 86,
#   'album': 'Favourite Worst Nightmare',
#   'release_date': '2007-04-22',
#   'duration': 253586,
#   'explicit': False,
#   'artist_name': 'Arctic Monkeys',
#   'artist_pop': 87,
#   'artist_genres': ['garage rock',
#    'modern rock',
#    'permanent wave',
#    'rock',
#    'sheffield indie'],
#   'danceability': 0.526,
#   'energy': 0.866,
#   'key': 0,
#   'loudness': -5.822,
#   'mode': 1,
#   'speechiness': 0.0568,
#   'acousticness': 0.00287,
#   'instrumentalness': 7.78e-05,
#   'liveness': 0.0945,
#   'valence': 0.248,
#   'tempo': 140.266,
#   'type': 'audio_features',
#   'id': '0BxE4FqsDD1Ot4YuBXwAPp',
#   'uri': 'spotify:track:0BxE4FqsDD1Ot4YuBXwAPp',
#   'track_href': 'https://api.spotify.com/v1/tracks/0BxE4FqsDD1Ot4YuBXwAPp',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0BxE4FqsDD1Ot4YuBXwAPp',
#   'duration_ms': 253587,
#   'time_signature': 4},
#  {'track_id': '2YlshLEFCJFjEoOlpLpcyU',
#   'track_name': 'Set Fire to the Rain',
#   'track_pop': 54,
#   'album': 'Set Fire to the Rain',
#   'release_date': '2011-07-04',
#   'duration': 242973,
#   'explicit': False,
#   'artist_name': 'Adele',
#   'artist_pop': 84,
#   'artist_genres': ['british soul', 'pop', 'pop soul', 'uk pop'],
#   'danceability': 0.603,
#   'energy': 0.67,
#   'key': 2,
#   'loudness': -3.882,
#   'mode': 0,
#   'speechiness': 0.0249,
#   'acousticness': 0.00408,
#   'instrumentalness': 1.68e-06,
#   'liveness': 0.112,
#   'valence': 0.446,
#   'tempo': 107.993,
#   'type': 'audio_features',
#   'id': '2YlshLEFCJFjEoOlpLpcyU',
#   'uri': 'spotify:track:2YlshLEFCJFjEoOlpLpcyU',
#   'track_href': 'https://api.spotify.com/v1/tracks/2YlshLEFCJFjEoOlpLpcyU',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2YlshLEFCJFjEoOlpLpcyU',
#   'duration_ms': 242974,
#   'time_signature': 4},
#  {'track_id': '0bVtevEgtDIeRjCJbK3Lmv',
#   'track_name': 'Welcome To The Jungle',
#   'track_pop': 79,
#   'album': 'Appetite For Destruction',
#   'release_date': '1987-07-21',
#   'duration': 272026,
#   'explicit': True,
#   'artist_name': "Guns N' Roses",
#   'artist_pop': 79,
#   'artist_genres': ['glam metal', 'hard rock', 'rock'],
#   'danceability': 0.447,
#   'energy': 0.954,
#   'key': 8,
#   'loudness': -8.069,
#   'mode': 1,
#   'speechiness': 0.0751,
#   'acousticness': 0.0235,
#   'instrumentalness': 0.403,
#   'liveness': 0.298,
#   'valence': 0.331,
#   'tempo': 123.453,
#   'type': 'audio_features',
#   'id': '0bVtevEgtDIeRjCJbK3Lmv',
#   'uri': 'spotify:track:0bVtevEgtDIeRjCJbK3Lmv',
#   'track_href': 'https://api.spotify.com/v1/tracks/0bVtevEgtDIeRjCJbK3Lmv',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0bVtevEgtDIeRjCJbK3Lmv',
#   'duration_ms': 272027,
#   'time_signature': 4},
#  {'track_id': '6I3mqTwhRpn34SLVafSH7G',
#   'track_name': 'Ghost',
#   'track_pop': 86,
#   'album': 'Justice',
#   'release_date': '2021-03-19',
#   'duration': 153190,
#   'explicit': False,
#   'artist_name': 'Justin Bieber',
#   'artist_pop': 89,
#   'artist_genres': ['canadian pop', 'pop'],
#   'danceability': 0.601,
#   'energy': 0.741,
#   'key': 2,
#   'loudness': -5.569,
#   'mode': 1,
#   'speechiness': 0.0478,
#   'acousticness': 0.185,
#   'instrumentalness': 2.91e-05,
#   'liveness': 0.415,
#   'valence': 0.441,
#   'tempo': 153.96,
#   'type': 'audio_features',
#   'id': '6I3mqTwhRpn34SLVafSH7G',
#   'uri': 'spotify:track:6I3mqTwhRpn34SLVafSH7G',
#   'track_href': 'https://api.spotify.com/v1/tracks/6I3mqTwhRpn34SLVafSH7G',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6I3mqTwhRpn34SLVafSH7G',
#   'duration_ms': 153190,
#   'time_signature': 4},
#  {'track_id': '4fouWK6XVHhzl78KzQ1UjL',
#   'track_name': 'abcdefu',
#   'track_pop': 84,
#   'album': 'abcdefu',
#   'release_date': '2021-08-13',
#   'duration': 168601,
#   'explicit': True,
#   'artist_name': 'GAYLE',
#   'artist_pop': 69,
#   'artist_genres': ['modern alternative pop'],
#   'danceability': 0.695,
#   'energy': 0.54,
#   'key': 4,
#   'loudness': -5.692,
#   'mode': 1,
#   'speechiness': 0.0493,
#   'acousticness': 0.299,
#   'instrumentalness': 0,
#   'liveness': 0.367,
#   'valence': 0.415,
#   'tempo': 121.932,
#   'type': 'audio_features',
#   'id': '4fouWK6XVHhzl78KzQ1UjL',
#   'uri': 'spotify:track:4fouWK6XVHhzl78KzQ1UjL',
#   'track_href': 'https://api.spotify.com/v1/tracks/4fouWK6XVHhzl78KzQ1UjL',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4fouWK6XVHhzl78KzQ1UjL',
#   'duration_ms': 168602,
#   'time_signature': 4},
#  {'track_id': '1Xi84slp6FryDSCbzq4UCD',
#   'track_name': 'Arcade',
#   'track_pop': 79,
#   'album': 'Arcade',
#   'release_date': '2019-03-07',
#   'duration': 183624,
#   'explicit': False,
#   'artist_name': 'Duncan Laurence',
#   'artist_pop': 68,
#   'artist_genres': ['dutch pop'],
#   'danceability': 0.45,
#   'energy': 0.329,
#   'key': 9,
#   'loudness': -12.603,
#   'mode': 0,
#   'speechiness': 0.0441,
#   'acousticness': 0.818,
#   'instrumentalness': 0.00109,
#   'liveness': 0.135,
#   'valence': 0.266,
#   'tempo': 71.884,
#   'type': 'audio_features',
#   'id': '1Xi84slp6FryDSCbzq4UCD',
#   'uri': 'spotify:track:1Xi84slp6FryDSCbzq4UCD',
#   'track_href': 'https://api.spotify.com/v1/tracks/1Xi84slp6FryDSCbzq4UCD',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1Xi84slp6FryDSCbzq4UCD',
#   'duration_ms': 183624,
#   'time_signature': 3}]

# %%
# check length of tracks - should be 509
len(tracks)
# Out:
# 509

# %% [markdown]
# This is now ready to be converted into a dataframe.

# %%
df = pd.DataFrame(tracks)

# %% [markdown]
# <h2>Data Manipulation & Formatting

# %% [markdown]
# Now I have an initial dataframe, but further manipulation and formatting needs to take place to get data ready for analysis.

# %%
pd.set_option('display.max_columns', None)

# %%
df.head(10)
# Out:
#                  track_id                                     track_name  \
# 0  0FE9t6xYkqWXU2ahLh6D8X                                   Shape of You
# 1  0sf12qNH5qcw8qpgymFOqD                                Blinding Lights
# 2  1rgnBhdG2JDFTbYkYRZAku                                   Dance Monkey
# 3  1OmcAT5Y8eg5bUPv9qJT4R                                       rockstar
# 4  7qEHsqek33rTcFNT9PFqLf                              Someone You Loved
# 5  1A6OTy97kk0mMdm78rHsm8  Sunflower - Spider-Man: Into the Spider-Verse
# 6  0JoaFxLgrqbWutREzcZBzS                                      One Dance
# 7  7BKLCZ1jbUBVqRi2FVlTVw                                         Closer
# 8  6VRghJeP6I0w1KxkdWFfIh                                       Believer
# 9  0TK2YIli7K1leLovkQiNik                                       Señorita
#
#    track_pop                                          album release_date  \
# 0         67                                   Shape of You   2017-01-06
# 1         17                                Blinding Lights   2019-11-29
# 2         63                                   Dance Monkey   2019-05-10
# 3          0                                       rockstar   2017-09-15
# 4         87        Divinely Uninspired To A Hellish Extent   2019-05-17
# 5          0  Sunflower (Spider-Man: Into the Spider-Verse)   2018-10-18
# 6          0                                      One Dance   2016-04-05
# 7         84                                         Closer   2016-07-29
# 8          0                                       Believer   2017-01-31
# 9         79                                       Señorita   2019-06-21
#
#    duration  explicit       artist_name  artist_pop  \
# 0    233712     False        Ed Sheeran          89
# 1    201573     False        The Weeknd          93
# 2    209754     False       Tones And I          70
# 3    218320      True       Post Malone          87
# 4    182160     False     Lewis Capaldi          80
# 5    158053     False       Post Malone          87
# 6    173974     False             Drake          97
# 7    244960     False  The Chainsmokers          79
# 8    203782     False   Imagine Dragons          87
# 9    190960     False      Shawn Mendes          83
#
#                                        artist_genres  danceability  energy  \
# 0                                      [pop, uk pop]         0.825   0.652
# 1     [canadian contemporary r&b, canadian pop, pop]         0.513   0.796
# 2                              [australian pop, pop]         0.826   0.593
# 3                        [dfw rap, melodic rap, rap]         0.580   0.531
# 4                                      [pop, uk pop]         0.501   0.405
# 5                        [dfw rap, melodic rap, rap]         0.753   0.498
# 6  [canadian hip hop, canadian pop, hip hop, rap,...         0.771   0.629
# 7  [dance pop, edm, electropop, pop, pop dance, t...         0.748   0.524
# 8                                [modern rock, rock]         0.770   0.787
# 9          [canadian pop, dance pop, pop, viral pop]         0.759   0.540
#
#    key  loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0    1    -3.183     0       0.0802       0.58100          0.000000    0.0931
# 1    1    -4.075     1       0.0629       0.00147          0.000209    0.0938
# 2    6    -6.401     0       0.0976       0.68800          0.000161    0.1700
# 3    5    -6.631     0       0.0776       0.12800          0.000127    0.1430
# 4    1    -5.679     1       0.0319       0.75100          0.000000    0.1050
# 5    2    -5.610     1       0.0504       0.55100          0.000000    0.0706
# 6    1    -5.790     1       0.0511       0.00802          0.002520    0.3560
# 7    8    -5.599     1       0.0338       0.41400          0.000000    0.1110
# 8   10    -4.402     0       0.1130       0.04820          0.000000    0.1080
# 9    9    -6.039     0       0.0287       0.03700          0.000000    0.0945
#
#    valence    tempo            type                      id  \
# 0    0.931   95.977  audio_features  0FE9t6xYkqWXU2ahLh6D8X
# 1    0.345  171.017  audio_features  0sf12qNH5qcw8qpgymFOqD
# 2    0.541   98.083  audio_features  1rgnBhdG2JDFTbYkYRZAku
# 3    0.141  159.786  audio_features  1OmcAT5Y8eg5bUPv9qJT4R
# 4    0.446  109.891  audio_features  7qEHsqek33rTcFNT9PFqLf
# 5    0.927   89.950  audio_features  1A6OTy97kk0mMdm78rHsm8
# 6    0.362  103.918  audio_features  0JoaFxLgrqbWutREzcZBzS
# 7    0.661   95.010  audio_features  7BKLCZ1jbUBVqRi2FVlTVw
# 8    0.699  125.013  audio_features  6VRghJeP6I0w1KxkdWFfIh
# 9    0.750  116.947  audio_features  0TK2YIli7K1leLovkQiNik
#
#                                     uri  \
# 0  spotify:track:0FE9t6xYkqWXU2ahLh6D8X
# 1  spotify:track:0sf12qNH5qcw8qpgymFOqD
# 2  spotify:track:1rgnBhdG2JDFTbYkYRZAku
# 3  spotify:track:1OmcAT5Y8eg5bUPv9qJT4R
# 4  spotify:track:7qEHsqek33rTcFNT9PFqLf
# 5  spotify:track:1A6OTy97kk0mMdm78rHsm8
# 6  spotify:track:0JoaFxLgrqbWutREzcZBzS
# 7  spotify:track:7BKLCZ1jbUBVqRi2FVlTVw
# 8  spotify:track:6VRghJeP6I0w1KxkdWFfIh
# 9  spotify:track:0TK2YIli7K1leLovkQiNik
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/0FE9t6xYkqWX...
# 1  https://api.spotify.com/v1/tracks/0sf12qNH5qcw...
# 2  https://api.spotify.com/v1/tracks/1rgnBhdG2JDF...
# 3  https://api.spotify.com/v1/tracks/1OmcAT5Y8eg5...
# 4  https://api.spotify.com/v1/tracks/7qEHsqek33rT...
# 5  https://api.spotify.com/v1/tracks/1A6OTy97kk0m...
# 6  https://api.spotify.com/v1/tracks/0JoaFxLgrqbW...
# 7  https://api.spotify.com/v1/tracks/7BKLCZ1jbUBV...
# 8  https://api.spotify.com/v1/tracks/6VRghJeP6I0w...
# 9  https://api.spotify.com/v1/tracks/0TK2YIli7K1l...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/0FE9...       233713
# 1  https://api.spotify.com/v1/audio-analysis/0sf1...       201573
# 2  https://api.spotify.com/v1/audio-analysis/1rgn...       209755
# 3  https://api.spotify.com/v1/audio-analysis/1Omc...       218320
# 4  https://api.spotify.com/v1/audio-analysis/7qEH...       182161
# 5  https://api.spotify.com/v1/audio-analysis/1A6O...       158053
# 6  https://api.spotify.com/v1/audio-analysis/0Joa...       173975
# 7  https://api.spotify.com/v1/audio-analysis/7BKL...       244960
# 8  https://api.spotify.com/v1/audio-analysis/6VRg...       203782
# 9  https://api.spotify.com/v1/audio-analysis/0TK2...       190960
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4
# 5               4
# 6               4
# 7               4
# 8               4
# 9               4

# %%
df.shape
# Out:
# (509, 28)

# %% [markdown]
# There are 509 rows, 28 columns in the dataframe.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 509 entries, 0 to 508
# Data columns (total 28 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   track_id          509 non-null    object
#  1   track_name        509 non-null    object
#  2   track_pop         509 non-null    int64
#  3   album             509 non-null    object
#  4   release_date      509 non-null    object
#  5   duration          509 non-null    int64
#  6   explicit          509 non-null    bool
#  7   artist_name       509 non-null    object
#  8   artist_pop        509 non-null    int64
#  9   artist_genres     509 non-null    object
#  10  danceability      509 non-null    float64
#  11  energy            509 non-null    float64
#  12  key               509 non-null    int64
#  13  loudness          509 non-null    float64
#  14  mode              509 non-null    int64
#  15  speechiness       509 non-null    float64
#  16  acousticness      509 non-null    float64
#  17  instrumentalness  509 non-null    float64
#  18  liveness          509 non-null    float64
#  19  valence           509 non-null    float64
#  20  tempo             509 non-null    float64
#  21  type              509 non-null    object
#  22  id                509 non-null    object
#  23  uri               509 non-null    object
#  24  track_href        509 non-null    object
#  25  analysis_url      509 non-null    object
#  26  duration_ms       509 non-null    int64
#  27  time_signature    509 non-null    int64
# dtypes: bool(1), float64(9), int64(7), object(11)
# memory usage: 108.0+ KB

# %% [markdown]
# Dataset contains no nulls. Release_date is an object which could be converted to datetime.

# %% [markdown]
# ### From looking at the first few rows
# - Some columns can be dropped (e.g. identifiers) as they won't be used for analysis.
#
# ### Columns to be modified
# - **release_date** - convert to datetime
# - **duration** - convert from milliseconds to seconds
# - **tempo** - round up
# - **key** - map to pitch class notation
# - **mode** - map to major/minor
# - **Audio metrics** - Mostly arbitrary floats, normalised between 0-1.
#
# ### New columns to be added
# - **year** - year component of release_date
# - **key_mode** - combination of key and mode

# %% [markdown]
# Drop following columns as they are either identifiers, contain a single value or duplicated columns

# %%
df.drop(['type', 'uri', 'track_href', 'analysis_url', 'duration_ms', 'id'], axis=1, inplace=True)

# %%
df.shape
# Out:
# (509, 22)

# %% [markdown]
# #### Release Date
# Convert release date column to datetime.
#
# Also create a new column 'year' for release year.

# %%
df['release_date'] =  pd.to_datetime(df['release_date'])
df['year'] = df['release_date'].dt.year

# %% [markdown]
# #### Duration
# Duration of the song in milliseconds. Convert to seconds and round up to whole number.

# %%
df['duration'] = round(df['duration']/1000)

# %% [markdown]
# #### Tempo
# This is the bpm of the track. Round up to whole number

# %%
df['tempo'] = round(df['tempo'])

# %% [markdown]
# #### Key
# Key is an integer that maps to [pitch class notation](https://en.wikipedia.org/wiki/Pitch_class) (Source - Spotify API Documentation)
#
# e.g. 0 = C, 1 = C#/Db, 2 = D ...
#
# Map the integer to the corresponding key.

# %%
pitch_class = {0: "C", 1: "C#/Db", 2: "D", 3: "D#/Eb", 4: "E", 5: "F", 6: "F#/Gb",
               7: "G", 8: "G#/Ab", 9: "A", 10: "A#/Bb", 11: "B"}

df['key'] = df['key'].map(pitch_class)

# %% [markdown]
# #### Mode
# This is an integer indicating the modality (major or minor) of a track. Major is represented by 1 and minor is 0.
#
# Map integers to corresponding mode.

# %%
mode = {0: 'Minor', 1: 'Major'}

df['mode'] = df['mode'].map(mode)

# %% [markdown]
# #### Key_Mode
# True key of a track is described by both its key and mode (e.g. C Major).
#
# Create a new column by combining Key and Mode

# %%
df['key_mode'] = df[['key', 'mode']].agg(' '.join, axis=1)

# %% [markdown]
# #### Audio features
#
# Following audio columns have been normalised by spotify to be between 0-1.
# - **Danceability** - suitability for dancing
# - **Energy** - measure of intensity and activity
# - **Speechiness** - presence of spoken words in a track
# - **Acousticness** - confidence measure of whether the track is acoustic
# - **Instrumentalness** - whether a track contains no vocals
# - **Liveness** - presence of an audience in the recording
# - **Valence** - musical positiveness conveyed by a track
#
# Multiply by 100 and round up to get a score-like metric (out of 100)

# %%
normalised_columns = ['danceability', 'energy', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence']

df[normalised_columns] = round(df[normalised_columns]*100)

# %% [markdown]
# <br>
# Check head to see the formatted data. It should now be ready for analysis.
#
# This is the top 10 most streamed songs on the playlist.

# %%
df.head(10)
# Out:
#                  track_id                                     track_name  \
# 0  0FE9t6xYkqWXU2ahLh6D8X                                   Shape of You
# 1  0sf12qNH5qcw8qpgymFOqD                                Blinding Lights
# 2  1rgnBhdG2JDFTbYkYRZAku                                   Dance Monkey
# 3  1OmcAT5Y8eg5bUPv9qJT4R                                       rockstar
# 4  7qEHsqek33rTcFNT9PFqLf                              Someone You Loved
# 5  1A6OTy97kk0mMdm78rHsm8  Sunflower - Spider-Man: Into the Spider-Verse
# 6  0JoaFxLgrqbWutREzcZBzS                                      One Dance
# 7  7BKLCZ1jbUBVqRi2FVlTVw                                         Closer
# 8  6VRghJeP6I0w1KxkdWFfIh                                       Believer
# 9  0TK2YIli7K1leLovkQiNik                                       Señorita
#
#    track_pop                                          album release_date  \
# 0         67                                   Shape of You   2017-01-06
# 1         17                                Blinding Lights   2019-11-29
# 2         63                                   Dance Monkey   2019-05-10
# 3          0                                       rockstar   2017-09-15
# 4         87        Divinely Uninspired To A Hellish Extent   2019-05-17
# 5          0  Sunflower (Spider-Man: Into the Spider-Verse)   2018-10-18
# 6          0                                      One Dance   2016-04-05
# 7         84                                         Closer   2016-07-29
# 8          0                                       Believer   2017-01-31
# 9         79                                       Señorita   2019-06-21
#
#    duration  explicit       artist_name  artist_pop  \
# 0     234.0     False        Ed Sheeran          89
# 1     202.0     False        The Weeknd          93
# 2     210.0     False       Tones And I          70
# 3     218.0      True       Post Malone          87
# 4     182.0     False     Lewis Capaldi          80
# 5     158.0     False       Post Malone          87
# 6     174.0     False             Drake          97
# 7     245.0     False  The Chainsmokers          79
# 8     204.0     False   Imagine Dragons          87
# 9     191.0     False      Shawn Mendes          83
#
#                                        artist_genres  danceability  energy  \
# 0                                      [pop, uk pop]          82.0    65.0
# 1     [canadian contemporary r&b, canadian pop, pop]          51.0    80.0
# 2                              [australian pop, pop]          83.0    59.0
# 3                        [dfw rap, melodic rap, rap]          58.0    53.0
# 4                                      [pop, uk pop]          50.0    40.0
# 5                        [dfw rap, melodic rap, rap]          75.0    50.0
# 6  [canadian hip hop, canadian pop, hip hop, rap,...          77.0    63.0
# 7  [dance pop, edm, electropop, pop, pop dance, t...          75.0    52.0
# 8                                [modern rock, rock]          77.0    79.0
# 9          [canadian pop, dance pop, pop, viral pop]          76.0    54.0
#
#      key  loudness   mode  speechiness  acousticness  instrumentalness  \
# 0  C#/Db    -3.183  Minor          8.0          58.0               0.0
# 1  C#/Db    -4.075  Major          6.0           0.0               0.0
# 2  F#/Gb    -6.401  Minor         10.0          69.0               0.0
# 3      F    -6.631  Minor          8.0          13.0               0.0
# 4  C#/Db    -5.679  Major          3.0          75.0               0.0
# 5      D    -5.610  Major          5.0          55.0               0.0
# 6  C#/Db    -5.790  Major          5.0           1.0               0.0
# 7  G#/Ab    -5.599  Major          3.0          41.0               0.0
# 8  A#/Bb    -4.402  Minor         11.0           5.0               0.0
# 9      A    -6.039  Minor          3.0           4.0               0.0
#
#    liveness  valence  tempo  time_signature  year     key_mode
# 0       9.0     93.0   96.0               4  2017  C#/Db Minor
# 1       9.0     34.0  171.0               4  2019  C#/Db Major
# 2      17.0     54.0   98.0               4  2019  F#/Gb Minor
# 3      14.0     14.0  160.0               4  2017      F Minor
# 4      10.0     45.0  110.0               4  2019  C#/Db Major
# 5       7.0     93.0   90.0               4  2018      D Major
# 6      36.0     36.0  104.0               4  2016  C#/Db Major
# 7      11.0     66.0   95.0               4  2016  G#/Ab Major
# 8      11.0     70.0  125.0               4  2017  A#/Bb Minor
# 9       9.0     75.0  117.0               4  2019      A Minor

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# Firstly, look at the summary statistics of the numeric columns.

# %%
df.describe().astype(int)
# Out:
#        track_pop  duration  artist_pop  danceability  energy  loudness  \
# count        509       509         509           509     509       509
# mean          66       218          80            67      64        -6
# std           26        43           8            13      17         2
# min            0        95          55            19       5       -20
# 25%           71       193          75            58      53        -7
# 50%           78       214          82            69      66        -5
# 75%           81       241          87            76      77        -4
# max           95       418         100            95      97        -2
#
#        speechiness  acousticness  instrumentalness  liveness  valence  tempo  \
# count          509           509               509       509      509    509
# mean             9            21                 0        16       49    119
# std              8            24                 4        13       22     26
# min              2             0                 0         2        6     59
# 25%              4             3                 0         9       34    100
# 50%              6            12                 0        12       49    119
# 75%             10            30                 0        19       67    136
# max             49            98                66        80       98    206
#
#        time_signature  year
# count             509   509
# mean                3  2013
# std                 0    10
# min                 1  1967
# 25%                 4  2013
# 50%                 4  2017
# 75%                 4  2018
# max                 5  2022

# %%
# Average duration in minutes
avg_duration = divmod(round(df['duration'].mean()), 60)
print(f'Average duration: {avg_duration[0]} minutes {avg_duration[1]} seconds')
# Out:
# Average duration: 3 minutes 39 seconds

# %% [markdown]
# ### Initial findings
# - Track popularity ranges from 0 to 95, artist popularity from 55 to 100
# - Average track duration is 3 minutes 39 seconds
# - Average danceability, energy is high (>50)
# - Speechiness is low (>66 = audiobooks, 33~66 = rap, <33 = music)
# - Acoustic & liveness low
# - Valence is around the halfway mark.
# - Average tempo is 119 bpm (e.g. uptown funk, billie jean)
# - Tracks from 1967 to 2022 (55 years).

# %% [markdown]
# Check the summary statistics of the non-numeric columns.

# %%
df.describe(include='object')
# Out:
#                       track_id  track_name            album artist_name  \
# count                      509         509              509         509
# unique                     509         505              451         271
# top     0FE9t6xYkqWXU2ahLh6D8X  Without Me  Stoney (Deluxe)  Ed Sheeran
# freq                         1           2                4          13
#
#            artist_genres    key   mode     key_mode
# count                509    509    509          509
# unique               232     12      2           24
# top     [dance pop, pop]  C#/Db  Major  C#/Db Major
# freq                  30     66    292           42

# %% [markdown]
# ### Initial findings
# - Top artist is Ed Sheeran
# - Top album is Stoney (Post Malone)
# - Top artist genre combination is [dance pop, pop]
# - Most frequent key is C#/Db
# - Just over half of the songs are in major mode

# %% [markdown]
# ## Analysis by Artist

# %% [markdown]
# ##### How many unique artists are there in the top 500?

# %%
df['artist_name'].nunique()
# Out:
# 271

# %% [markdown]
# ##### Who are the top artists?
#
# So I know Ed Sheeran is the top artist, but who else is there and how many songs do they have?

# %%
top_15_artists = df['artist_name'].value_counts().nlargest(15)

ax = sns.barplot(y=top_15_artists.index, x=top_15_artists, palette='viridis')
ax.set(xlabel='Number of songs', title='Top 15 artists and total number of songs')
ax.axes.get_xaxis().set_visible(False)
ax.set_frame_on(False)
for artist_index, count in enumerate(top_15_artists):
    ax.text(x=count, y=artist_index + 0.1, s=count, color='black', fontsize=8)
plt.show()

# %% [markdown]
# <br>
# Ed Sheeran has the most streamed songs, at 13 songs total.
#
# Followed by Post malone (12), Ariana Grande (11), Maroon 5/Drake/The Weeknd (10)

# %% [markdown]
# ##### What percentage share of total songs do the artists have?
#
# If I sorted the artists into bins based on the total number of songs they have in the playlist, what share of the total songs will each group have?

# %%
df_artist = df['artist_name'].value_counts().reset_index(name='count')
df_artist.rename(columns={'index': 'artist_name'}, inplace=True)

# %% [markdown]
# Create 4 bins and sort artists into the following groups
# - 1-3 songs
# - 4-6 songs
# - 7-9 songs
# - 10-13 songs

# %%
df_artist['bin'] = pd.cut(df_artist['count'], bins=4, right=False, labels=['1-3', '4-6', '7-9', '10-13'])

# %% [markdown]
# <br>
# Calculate the percentage of artists that fall into each bin.

# %%
pct_artists = df_artist.groupby('bin')['artist_name'].count()/len(df_artist)*100

# %%
pct_artists
# Out:
# bin
# 1-3      88.560886
# 4-6       5.904059
# 7-9       3.321033
# 10-13     2.214022
# Name: artist_name, dtype: float64

# %% [markdown]
# <br>
# Calculate the cumulative percentage of the artists in each bin.

# %%
pct_artists.sort_values(ascending=True, inplace=True)
pct_artists_cs = np.cumsum(pct_artists)
pct_artists_cs.values
# Out:
# array([  2.21402214,   5.53505535,  11.43911439, 100.        ])

# %% [markdown]
# <br>
# Calculate the cumulative percentage of the songs by each bin.

# %%
pct_songs = df_artist.groupby('bin')['count'].sum()/len(df)*100

# %%
pct_songs
# Out:
# bin
# 1-3      58.939096
# 4-6      14.734774
# 7-9      13.359528
# 10-13    12.966601
# Name: count, dtype: float64

# %%
pct_songs.sort_values(ascending=True, inplace=True)
pct_songs_cs = np.cumsum(pct_songs)
pct_songs_cs.values
# Out:
# array([ 12.96660118,  26.32612967,  41.06090373, 100.        ])

# %% [markdown]
# Plot this on a 100% stacked chart, to show relative percentage of the artists in each bin and their relative share of songs in the top 500 playlist

# %%
xvalues = ['Artist bin', 'Songs']
colours = ['lightsalmon', 'lightseagreen', 'steelblue', 'midnightblue']
bins = df_artist['bin'].unique()

plt.figure(figsize=(8,6))
for i in reversed(range(len(pct_songs_cs.values))):
    plt.bar(x=xvalues, height=[pct_artists_cs.values[i], pct_songs_cs.values[i]], color=colours[i], width=0.5, label=f'{bins[i]} songs')
    plt.annotate(f'{round(pct_artists_cs.values[i])}%', xy=(-0.05, pct_artists_cs.values[i]-2.2), color='white', size=8)
    plt.annotate(f'{round(pct_songs_cs.values[i])}%', xy=(0.95, pct_songs_cs.values[i]-2.5), color='white', size=8)

plt.title('Top 500 songs distribution by artist bins')
plt.ylabel('Percentage(%)')
plt.legend(loc='center right')
plt.xlim([-0.5,2])
plt.show()

# %% [markdown]
# Majority of artists only have 1-3 songs (89%) in the top 500.
# But a small percentage of them have 4 or more songs (11%):
# - 6% have 4-6 songs
# - 3% have 7-9 songs
# - 2% have 10-13 songs
#
# However this relatively small group of artists (> 4 songs) make up **41%** of the total songs in the playlist.

# %% [markdown]
# ## Analysis by Artist Genres

# %% [markdown]
# Each artist has their own musical style (genre) which usually spans across multiple genres.

# %% [markdown]
# ##### What are the most frequent artist genres?

# %%
df[['artist_name', 'artist_genres']].head(10)
# Out:
#         artist_name                                      artist_genres
# 0        Ed Sheeran                                      [pop, uk pop]
# 1        The Weeknd     [canadian contemporary r&b, canadian pop, pop]
# 2       Tones And I                              [australian pop, pop]
# 3       Post Malone                        [dfw rap, melodic rap, rap]
# 4     Lewis Capaldi                                      [pop, uk pop]
# 5       Post Malone                        [dfw rap, melodic rap, rap]
# 6             Drake  [canadian hip hop, canadian pop, hip hop, rap,...
# 7  The Chainsmokers  [dance pop, edm, electropop, pop, pop dance, t...
# 8   Imagine Dragons                                [modern rock, rock]
# 9      Shawn Mendes          [canadian pop, dance pop, pop, viral pop]

# %% [markdown]
# There are some issues here:
# - artist_genres column contains lists of varying lengths
# - If the artist appears multiple times, their genres will be duplicated

# %% [markdown]
# First check how many unique artist genres there are.

# %%
artist_genres = [genre for genre_list in df['artist_genres'] for genre in genre_list]
len(set(artist_genres))
# Out:
# 224

# %% [markdown]
# By using 'explode', create a row for each genre in the list.

# %%
df.explode('artist_genres')
# Out:
#                    track_id             track_name  track_pop  \
# 0    0FE9t6xYkqWXU2ahLh6D8X           Shape of You         67
# 0    0FE9t6xYkqWXU2ahLh6D8X           Shape of You         67
# 1    0sf12qNH5qcw8qpgymFOqD        Blinding Lights         17
# 1    0sf12qNH5qcw8qpgymFOqD        Blinding Lights         17
# 1    0sf12qNH5qcw8qpgymFOqD        Blinding Lights         17
# ..                      ...                    ...        ...
# 505  0bVtevEgtDIeRjCJbK3Lmv  Welcome To The Jungle         79
# 506  6I3mqTwhRpn34SLVafSH7G                  Ghost         86
# 506  6I3mqTwhRpn34SLVafSH7G                  Ghost         86
# 507  4fouWK6XVHhzl78KzQ1UjL                abcdefu         84
# 508  1Xi84slp6FryDSCbzq4UCD                 Arcade         79
#
#                         album release_date  duration  explicit  \
# 0                Shape of You   2017-01-06     234.0     False
# 0                Shape of You   2017-01-06     234.0     False
# 1             Blinding Lights   2019-11-29     202.0     False
# 1             Blinding Lights   2019-11-29     202.0     False
# 1             Blinding Lights   2019-11-29     202.0     False
# ..                        ...          ...       ...       ...
# 505  Appetite For Destruction   1987-07-21     272.0      True
# 506                   Justice   2021-03-19     153.0     False
# 506                   Justice   2021-03-19     153.0     False
# 507                   abcdefu   2021-08-13     169.0      True
# 508                    Arcade   2019-03-07     184.0     False
#
#          artist_name  artist_pop              artist_genres  danceability  \
# 0         Ed Sheeran          89                        pop          82.0
# 0         Ed Sheeran          89                     uk pop          82.0
# 1         The Weeknd          93  canadian contemporary r&b          51.0
# 1         The Weeknd          93               canadian pop          51.0
# 1         The Weeknd          93                        pop          51.0
# ..               ...         ...                        ...           ...
# 505    Guns N' Roses          79                       rock          45.0
# 506    Justin Bieber          89               canadian pop          60.0
# 506    Justin Bieber          89                        pop          60.0
# 507            GAYLE          69     modern alternative pop          70.0
# 508  Duncan Laurence          68                  dutch pop          45.0
#
#      energy    key  loudness   mode  speechiness  acousticness  \
# 0      65.0  C#/Db    -3.183  Minor          8.0          58.0
# 0      65.0  C#/Db    -3.183  Minor          8.0          58.0
# 1      80.0  C#/Db    -4.075  Major          6.0           0.0
# 1      80.0  C#/Db    -4.075  Major          6.0           0.0
# 1      80.0  C#/Db    -4.075  Major          6.0           0.0
# ..      ...    ...       ...    ...          ...           ...
# 505    95.0  G#/Ab    -8.069  Major          8.0           2.0
# 506    74.0      D    -5.569  Major          5.0          18.0
# 506    74.0      D    -5.569  Major          5.0          18.0
# 507    54.0      E    -5.692  Major          5.0          30.0
# 508    33.0      A   -12.603  Minor          4.0          82.0
#
#      instrumentalness  liveness  valence  tempo  time_signature  year  \
# 0                 0.0       9.0     93.0   96.0               4  2017
# 0                 0.0       9.0     93.0   96.0               4  2017
# 1                 0.0       9.0     34.0  171.0               4  2019
# 1                 0.0       9.0     34.0  171.0               4  2019
# 1                 0.0       9.0     34.0  171.0               4  2019
# ..                ...       ...      ...    ...             ...   ...
# 505              40.0      30.0     33.0  123.0               4  1987
# 506               0.0      42.0     44.0  154.0               4  2021
# 506               0.0      42.0     44.0  154.0               4  2021
# 507               0.0      37.0     42.0  122.0               4  2021
# 508               0.0      14.0     27.0   72.0               3  2019
#
#         key_mode
# 0    C#/Db Minor
# 0    C#/Db Minor
# 1    C#/Db Major
# 1    C#/Db Major
# 1    C#/Db Major
# ..           ...
# 505  G#/Ab Major
# 506      D Major
# 506      D Major
# 507      E Major
# 508      A Minor
#
# [1813 rows x 24 columns]

# %% [markdown]
# Subset the artist name and artist genres columns. Then drop duplicates to ensure each artist's genres appear only once.

# %%
genres_dupe_removed = df.explode('artist_genres')[['artist_name', 'artist_genres']].drop_duplicates()

# %%
genres_dupe_removed.head(10)
# Out:
#    artist_name              artist_genres
# 0   Ed Sheeran                        pop
# 0   Ed Sheeran                     uk pop
# 1   The Weeknd  canadian contemporary r&b
# 1   The Weeknd               canadian pop
# 1   The Weeknd                        pop
# 2  Tones And I             australian pop
# 2  Tones And I                        pop
# 3  Post Malone                    dfw rap
# 3  Post Malone                melodic rap
# 3  Post Malone                        rap

# %% [markdown]
# <br>
# Now plot the top 20 artist genres.

# %%
top_20_genres = genres_dupe_removed['artist_genres'].value_counts().nlargest(20)

# %%
ax = sns.barplot(y=top_20_genres.index, x=top_20_genres)
ax.set(xlabel='Count', title='Top 20 artist genres')
ax.axes.get_xaxis().set_visible(False)
ax.set_frame_on(False)
for genre_index, count in enumerate(top_20_genres):
    ax.text(x=count, y=genre_index + 0.1, s=count, color='black', fontsize=8)
plt.show()

# %% [markdown]
# - Pop is by far the most frequent - 133 artists (out of 271) have it in their list of genres.
# - Notice that there are a lot of sub-genres of pop.

# %% [markdown]
# ## Analysis by Key and Mode

# %% [markdown]
# Each track has a key and mode that it's composed in (e.g. C major).
#
# ##### Are some keys used more frequently than others in popular songs?

# %%
ax = sns.barplot(y=df['key'].value_counts(), x=df['key'].value_counts().index)
ax.set(title='Number of songs composed under each key')
ax.set_frame_on(False)
ax.axes.get_yaxis().set_visible(False)
plt.xticks(rotation=45)
for key_index, count in enumerate(df['key'].value_counts()):
    ax.text(x=key_index-0.2, y=count+0.5, s=count, color='black', fontsize=8)
plt.show()

# %% [markdown]
# - C#/Db is the most frequent key.
# - D#/Eb is least used.
#
#
# Some examples of songs in each key:
# - C#/Db - Shape of you, blinding lights, one dance
# - C - bohemian rhapsody, uptown funk
# - B - heat waves, dont start now
# - E - Photograph
# - G - bad guy, starboy
# - F#/Gb - dance monkey

# %% [markdown]
# Key alone doesn't paint the whole picture, mode should also be considered (major/minor).
#
# Plot the key & mode in a similar bar chart.

# %%
plt.figure(figsize=(15,10)) 
ax = sns.barplot(y=df['key_mode'].value_counts(), x=df['key_mode'].value_counts().index)
for key_index, count in enumerate(df['key_mode'].value_counts()):
    ax.text(x=key_index-0.2, y=count+0.5, s=count, color='black', fontsize=9)
plt.xticks(rotation=45)
ax.set_frame_on(False)
ax.axes.get_yaxis().set_visible(False)
plt.title('Number of songs composed under each key & mode')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# - C#/Db major is still the most popular
# - Unlike previous chart, D major is the 3rd most popular
# - D#/Eb Minor and D minor are very unpopular

# %% [markdown]
# #### Mode - What percentage of songs are major or minor?

# %%
round(df['mode'].value_counts()/len(df)*100)
# Out:
# Major    57.0
# Minor    43.0
# Name: mode, dtype: float64

# %% [markdown]
# 57% of songs are in major, 43% in minor.

# %% [markdown]
# #### Explicit - What percentage of songs are explicit?

# %%
round(df['explicit'].value_counts()/len(df)*100)
# Out:
# False    69.0
# True     31.0
# Name: explicit, dtype: float64

# %% [markdown]
# 31% are explicit, 69% are non-explicit.

# %% [markdown]
# #### Time Signature - How many different time signatures are there?

# %%
round(df['time_signature'].value_counts()/len(df)*100)
# Out:
# 4    95.0
# 3     4.0
# 5     1.0
# 1     0.0
# Name: time_signature, dtype: float64

# %% [markdown]
# In total 4 different time signatures, with majority (95%) being 4/4.

# %% [markdown]
# ## Analysis of Audio Features

# %% [markdown]
# There are many audio features of a track that are calculated by the Spotify algorithms.

# %% [markdown]
# #### Is there any correlation between these features?

# %%
corr = df.corr().round(2)
mask = np.triu(np.ones_like(corr, dtype=bool))

plt.figure(figsize=(15,12)) 
ax = sns.heatmap(corr, mask=mask, cmap='Spectral', annot=True)

# %% [markdown]
# #### Initial Findings
# - As a song gets energetic, loudness also increases
# - If a song is more acousic, energy and loudness tends to be lower
# - As acousticness increases, valence decreases
# - Happier sounding songs tend to be more danceable, energetic and loud
#
# #### Looking at 'year', as time goes on:
# - Duration getting shorter
# - Loudness, danceability, speechiness tends to increase
# - Valence tends to decrease

# %% [markdown]
# Quick look at a scatter plot of energy and loudness (strong +ve corr)

# %%
plt.scatter(df['energy'], df['loudness'])
plt.xlabel('Energy')
plt.ylabel('Loudness (dB)')
plt.title('Energy vs loudness in a song')
plt.show()

# %% [markdown]
# Scatter plot of energy and acousticness (-ve corr)

# %%
plt.scatter(df['energy'], df['acousticness'])
plt.xlabel('Energy')
plt.ylabel('Acousticness')
plt.title('Energy vs acousticness in a song')
plt.show()

# %% [markdown]
# #### Compare the distribution of each audio feature.

# %% [markdown]
# Here I am only including columns having values out of 100.

# %%
df_features = df.select_dtypes(include=['float64', bool]).drop(['tempo', 'duration', 'loudness', 'explicit'], axis=1)

# %%
sns.displot(df_features, kind='kde', fill=True, height=4, aspect=2)
plt.title('Distribution of audio features')
plt.xlabel('Audio feature (out of 100)')
plt.show()

# %% [markdown]
# Instrumentalness has very narrow distribution around 0. Indicates most songs in the top 500 are not instrumental.
#
# Try remove instrumentalness for better comparison of other features.

# %%
sns.displot(df_features.drop('instrumentalness', axis=1), kind='kde', fill=True, height=4, aspect=2)
plt.title('Distribution of audio features (without instrumentalness)')
plt.xlabel('Audio feature (out of 100)')
plt.show()

# %% [markdown]
# Danceability and energy has similar distribution. Tend to be higher.
# Speechiness, liveness have narrower distribution. Tend to be lower.
# Acousticness and Valence have high spread.

# %% [markdown]
# #### See the same data in a boxplot

# %%
plt.figure(figsize=(10,7)) 
sns.boxplot(data=df_features, palette='Set2', linewidth=0.7, width=0.5, fliersize=2)
plt.title('Boxplot of audio features')
plt.ylabel('Audio feature (out of 100)')
plt.show()

# %% [markdown]
# On average, songs in the top 500 tend to be:
# - Danceable and energetic
# - Not very acoustic
# - Little presence of audience
# - Not instrumental
# - Neutral sounding (happy/sad)
#
# Speechiness is harder to analyse as anything between 0 - 0.66 is typical for music, with 0.33 - 0.66 having more words (e.g. rap).

# %% [markdown]
# ### Change over the years
#
# From the correlation matrix, there was indication that some features were changing over the years.

# %% [markdown]
# #### How many songs in the top 500 were released under each year?

# %%
plt.figure(figsize=(15,10)) 
ax = sns.barplot(y=df['year'].value_counts(), x=df['year'].value_counts().index)
ax.set(xlabel='Year released', title='Number of songs released in each year')
ax.set_frame_on(False)
ax.axes.get_yaxis().set_visible(False)
plt.xticks(rotation=45)
for year_index, count in enumerate(df['year'].value_counts().sort_index()):
         ax.text(x=year_index-0.2, y=count+0.5, s=count, color='black', fontsize=8)
plt.show()

# %% [markdown]
# - Spotify was founded in 2006, taking off from ~2010
# - Bias towards modern, recently released music. Makes sense as the playlist contains the **most streamed songs on spotify**.
# - Less data for last few years

# %% [markdown]
# From the correlation matrix, it was identified that potentially:
#
# - Duration of songs are getting shorter
# - Loudness, danceability, speechiness tends to increase
# - Valence tends to decrease

# %% [markdown]
# #### Is there a trend in audio features over time?
#
# Here I've only included data post 2010 to exclude small sample sizes.

# %%
df_year = df.select_dtypes(include=['float64', bool, 'int64' ]).drop(['time_signature','tempo', 'duration', 'loudness', 'track_pop', 'artist_pop', 'explicit'], axis=1)

# %%
plt.figure(figsize=(15,10)) 
for column in df_year.columns:    
    if column != 'year':
        sns.lineplot(data=df[df['year'] > 2010], x='year', y= column, legend='brief', label=column)
        
plt.title('Plot of average audio features from year 2011 - 2022')        
plt.ylabel('Feature')
plt.legend(loc='best')
plt.ylim(0,110)
plt.show()

# %% [markdown]
# Can't say if there is an obvious trend from the above line plot.
#
# Danceability potentially slightly trending up but can't conclude.

# %% [markdown]
# #### Is there a trend in song duration over time?
#
# Again subset data for post 2010 and look at the average duration.

# %%
df_post_2010 = df[df['year'] > 2010]

# %%
plt.figure(figsize=(15,10)) 
sns.lineplot(data=df[df['year'] > 2010], x='year', y= 'duration')
plt.ylabel('Duration (s)')
plt.title('Average duration of tracks from year 2011 - 2022')
plt.show()

# %%
round(df_post_2010.groupby('year')['duration'].mean())
# Out:
# year
# 2011    245.0
# 2012    215.0
# 2013    248.0
# 2014    228.0
# 2015    223.0
# 2016    226.0
# 2017    208.0
# 2018    203.0
# 2019    197.0
# 2020    204.0
# 2021    202.0
# 2022    173.0
# Name: duration, dtype: float64

# %% [markdown]
# Duration of popular songs does appear to be trending down over the last decade, even when ignoring 2022 which only had two tracks.
#
# Shaving off around 43 seconds from 2011 vs 2021.

# %% [markdown]
# ### Conclusion

# %% [markdown]
# So to summarise, in the top 500 most streamed songs of spotify:
#
# - **Pop** (and pop sub-genre) artists more likely to feature.
# - **C#/Db major** tends to be most popular key. **D minor** is the least popular.
# - Songs tend to be in **major** mode and have standard time signature (4/4).
# - Average duration have been getting **shorter** over time.
# - Songs tend to be more **danceable** and **energetic**.

# %% [markdown]
# ### Notes and Improvements

# %% [markdown]
# This playlist a small dataset and is mostly biased towards recent music. It is affected by the founding date and popularity of spotify as a streaming platform.
#
# There is also biased towards western music.
#
# - Total play count of a song not available
# - Track genre isn't provided
# - Some charts would have been a lot easier with tableau
# - Better way to annotate plots
# - Didn't draw as much insight from audio features. Rather arbitrary measures.
#
# Could have been more interesting to aggregate playlists from each decade so there's equal weight.
